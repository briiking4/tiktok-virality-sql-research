# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://admin:sql_2021@sql-project.chikfrkoyewh.us-east-1.rds.amazonaws.com/spotify_tiktok?charset=utf8')

# %%
AUTH_TOKEN = ''
headers = {'Authorization': f'Bearer {AUTH_TOKEN}'}

# %%
playlist_id = '37i9dQZF1DX2L0iB23Enbq'

playlist_endpoint_url = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'

params = {'limit': 50}

playlist_api_request = requests.get(playlist_endpoint_url, params, headers = headers)

# %%
playlist_api_response = json.loads(playlist_api_request.text)

# %%
playlist_api_response
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2L0iB23Enbq/tracks?offset=0&limit=50',
#  'items': [{'added_at': '2021-03-29T23:10:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#        'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#        'id': '5VZn4mB8pS40aE0kujdX2Y',
#        'name': 'Chloe George',
#        'type': 'artist',
#        'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6W4tUP2tcem0izGTVzxx5g'},
#      'href': 'https://api.spotify.com/v1/albums/6W4tUP2tcem0izGTVzxx5g',
#      'id': '6W4tUP2tcem0izGTVzxx5g',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b6327459f5454a084d656f0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b6327459f5454a084d656f0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b6327459f5454a084d656f0',
#        'width': 64}],
#      'name': 'ghost town (voice memo)',
#      'release_date': '2021-03-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6W4tUP2tcem0izGTVzxx5g'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#       'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#       'id': '5VZn4mB8pS40aE0kujdX2Y',
#       'name': 'Chloe George',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 137250,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72104942'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0PKAijroHpnEtdY20bkGdr'},
#     'href': 'https://api.spotify.com/v1/tracks/0PKAijroHpnEtdY20bkGdr',
#     'id': '0PKAijroHpnEtdY20bkGdr',
#     'is_local': False,
#     'name': 'ghost town (voice memo)',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1dc760d2bfd12adfe1d5090dc48f35161242799d?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0PKAijroHpnEtdY20bkGdr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-03-21T02:01:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#        'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#        'id': '2KsP6tYLJlTBvSUxnwlVWa',
#        'name': 'Mike Posner',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2nnIlWcriIqcJtjduWcTRl'},
#      'href': 'https://api.spotify.com/v1/albums/2nnIlWcriIqcJtjduWcTRl',
#      'id': '2nnIlWcriIqcJtjduWcTRl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a98ac59b1f31230990d941a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a98ac59b1f31230990d941a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a98ac59b1f31230990d941a2',
#        'width': 64}],
#      'name': '31 Minutes to Takeoff',
#      'release_date': '2010-08-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2nnIlWcriIqcJtjduWcTRl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#       'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#       'id': '2KsP6tYLJlTBvSUxnwlVWa',
#       'name': 'Mike Posner',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 196813,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJAY1000077'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6jg5SRvdGxvJ0DzNV0UqEK'},
#     'href': 'https://api.spotify.com/v1/tracks/6jg5SRvdGxvJ0DzNV0UqEK',
#     'id': '6jg5SRvdGxvJ0DzNV0UqEK',
#     'is_local': False,
#     'name': "Please Don't Go",
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/66706c36ab06b681bc2b5d269f7387ec0110e16f?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6jg5SRvdGxvJ0DzNV0UqEK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-01T02:35:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#        'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#        'id': '7jVv8c5Fj3E9VhNjxT4snq',
#        'name': 'Lil Nas X',
#        'type': 'artist',
#        'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5iZytG7j5DDp9RlsmkGI97'},
#      'href': 'https://api.spotify.com/v1/albums/5iZytG7j5DDp9RlsmkGI97',
#      'id': '5iZytG7j5DDp9RlsmkGI97',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ddb9cf14094fa5b3f8683b14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ddb9cf14094fa5b3f8683b14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ddb9cf14094fa5b3f8683b14',
#        'width': 64}],
#      'name': 'MONTERO (Call Me By Your Name)',
#      'release_date': '2021-03-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5iZytG7j5DDp9RlsmkGI97'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 137875,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM12100531'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3BZEcbdtXQSo7OrvKRJ6mb'},
#     'href': 'https://api.spotify.com/v1/tracks/3BZEcbdtXQSo7OrvKRJ6mb',
#     'id': '3BZEcbdtXQSo7OrvKRJ6mb',
#     'is_local': False,
#     'name': 'MONTERO (Call Me By Your Name)',
#     'popularity': 99,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3BZEcbdtXQSo7OrvKRJ6mb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-03-05T00:21:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IJczjB0fJ04gs4uvP0Fli'},
#        'href': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli',
#        'id': '4IJczjB0fJ04gs4uvP0Fli',
#        'name': 'Gym Class Heroes',
#        'type': 'artist',
#        'uri': 'spotify:artist:4IJczjB0fJ04gs4uvP0Fli'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Ug3M4a8wAEebndVIF65fX'},
#      'href': 'https://api.spotify.com/v1/albums/4Ug3M4a8wAEebndVIF65fX',
#      'id': '4Ug3M4a8wAEebndVIF65fX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f335d8387c3658831112f914',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f335d8387c3658831112f914',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f335d8387c3658831112f914',
#        'width': 64}],
#      'name': 'The Papercut Chronicles',
#      'release_date': '2005-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:4Ug3M4a8wAEebndVIF65fX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IJczjB0fJ04gs4uvP0Fli'},
#       'href': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli',
#       'id': '4IJczjB0fJ04gs4uvP0Fli',
#       'name': 'Gym Class Heroes',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IJczjB0fJ04gs4uvP0Fli'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 243773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US56V0407211'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Lhdl74nwwVGOE2Gv35QuK'},
#     'href': 'https://api.spotify.com/v1/tracks/2Lhdl74nwwVGOE2Gv35QuK',
#     'id': '2Lhdl74nwwVGOE2Gv35QuK',
#     'is_local': False,
#     'name': "Cupid's Chokehold / Breakfast in America",
#     'popularity': 87,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aa1ffc19b8b6b8cea5446b81b5ec3d1254231c94?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:2Lhdl74nwwVGOE2Gv35QuK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-03-30T20:23:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AR',
#       'AU',
#       'BN',
#       'BO',
#       'BZ',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'GT',
#       'GY',
#       'HK',
#       'HN',
#       'ID',
#       'IN',
#       'KH',
#       'KR',
#       'LA',
#       'MO',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PY',
#       'SG',
#       'SR',
#       'SV',
#       'TH',
#       'TL',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1uyf3l2d4XYwiEqAb7t7fX'},
#      'href': 'https://api.spotify.com/v1/albums/1uyf3l2d4XYwiEqAb7t7fX',
#      'id': '1uyf3l2d4XYwiEqAb7t7fX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27378c6c624a95d1bd02ba1fa02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0278c6c624a95d1bd02ba1fa02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485178c6c624a95d1bd02ba1fa02',
#        'width': 64}],
#      'name': 'Doo-Wops & Hooligans',
#      'release_date': '2010-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1uyf3l2d4XYwiEqAb7t7fX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'BN',
#      'BO',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'KH',
#      'KR',
#      'LA',
#      'MO',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PY',
#      'SG',
#      'SR',
#      'SV',
#      'TH',
#      'TL',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'disc_number': 1,
#     'duration_ms': 217866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21001985'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/161DnLWsx1i3u1JT05lzqU'},
#     'href': 'https://api.spotify.com/v1/tracks/161DnLWsx1i3u1JT05lzqU',
#     'id': '161DnLWsx1i3u1JT05lzqU',
#     'is_local': False,
#     'name': 'Talking to the Moon',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/97de5b6d487f491cddfb427c1612f45f5b3c9388?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:161DnLWsx1i3u1JT05lzqU'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-02-19T05:00:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uU7g3DNSbsu0QjSEqZtEd'},
#        'href': 'https://api.spotify.com/v1/artists/1uU7g3DNSbsu0QjSEqZtEd',
#        'id': '1uU7g3DNSbsu0QjSEqZtEd',
#        'name': 'Masked Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uU7g3DNSbsu0QjSEqZtEd'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/023KmMyB2DNZR3V8YKoET9'},
#      'href': 'https://api.spotify.com/v1/albums/023KmMyB2DNZR3V8YKoET9',
#      'id': '023KmMyB2DNZR3V8YKoET9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273214ace0e5ba30b74d19efb19',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02214ace0e5ba30b74d19efb19',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851214ace0e5ba30b74d19efb19',
#        'width': 64}],
#      'name': 'Astronaut In The Ocean',
#      'release_date': '2019-06-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:023KmMyB2DNZR3V8YKoET9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uU7g3DNSbsu0QjSEqZtEd'},
#       'href': 'https://api.spotify.com/v1/artists/1uU7g3DNSbsu0QjSEqZtEd',
#       'id': '1uU7g3DNSbsu0QjSEqZtEd',
#       'name': 'Masked Wolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uU7g3DNSbsu0QjSEqZtEd'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 132780,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUFXV1900105'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0jdso14vaFnpRazMLEZovF'},
#     'href': 'https://api.spotify.com/v1/tracks/0jdso14vaFnpRazMLEZovF',
#     'id': '0jdso14vaFnpRazMLEZovF',
#     'is_local': False,
#     'name': 'Astronaut In The Ocean',
#     'popularity': 56,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0jdso14vaFnpRazMLEZovF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-05T21:41:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#        'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#        'id': '1LZEQNv7sE11VDY3SdxQeN',
#        'name': 'Bee Gees',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4vAhQeeWkSjVn0p5GAaLBx'},
#      'href': 'https://api.spotify.com/v1/albums/4vAhQeeWkSjVn0p5GAaLBx',
#      'id': '4vAhQeeWkSjVn0p5GAaLBx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273324045726c4b0deb6cb7c875',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02324045726c4b0deb6cb7c875',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851324045726c4b0deb6cb7c875',
#        'width': 64}],
#      'name': 'How Can You Mend A Broken Heart',
#      'release_date': '2020-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:4vAhQeeWkSjVn0p5GAaLBx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#       'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#       'id': '1LZEQNv7sE11VDY3SdxQeN',
#       'name': 'Bee Gees',
#       'type': 'artist',
#       'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196213,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLF057790033'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2cX2coZS1PYBfPs8wgbdWE'},
#     'href': 'https://api.spotify.com/v1/tracks/2cX2coZS1PYBfPs8wgbdWE',
#     'id': '2cX2coZS1PYBfPs8wgbdWE',
#     'is_local': False,
#     'name': 'More Than A Woman - From "Saturday Night Fever" Soundtrack',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0396e55e0afb98e464697b7e749b4b40d3a69363?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:2cX2coZS1PYBfPs8wgbdWE'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-04-05T00:47:48Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#      'href': 'https://api.spotify.com/v1/albums/5dGWwsZ9iB2Xc3UKR0gif2',
#      'id': '5dGWwsZ9iB2Xc3UKR0gif2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e6f407c7f3a0ec98845e4431',
#        'width': 64}],
#      'name': 'Justice',
#      'release_date': '2021-03-19',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5dGWwsZ9iB2Xc3UKR0gif2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#       'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#       'id': '20wkVLutqVOYrc0kxFs7rA',
#       'name': 'Daniel Caesar',
#       'type': 'artist',
#       'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 198081,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72102636'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI'},
#     'href': 'https://api.spotify.com/v1/tracks/4iJyoBOLtHqaGxP12qzhQI',
#     'id': '4iJyoBOLtHqaGxP12qzhQI',
#     'is_local': False,
#     'name': 'Peaches (feat. Daniel Caesar & Giveon)',
#     'popularity': 100,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2d914ef1e42235bd50ba4f1c08f84d84ebb0bebc?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:4iJyoBOLtHqaGxP12qzhQI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-03-15T21:46:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#        'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#        'id': '2vnB6tuQMaQpORiRdvXF9H',
#        'name': 'Beach Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#      'available_markets': ['AU', 'NZ'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1PAsUJFVKxmdofGFsFU3Df'},
#      'href': 'https://api.spotify.com/v1/albums/1PAsUJFVKxmdofGFsFU3Df',
#      'id': '1PAsUJFVKxmdofGFsFU3Df',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc0e3acd005a2f3d136525cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc0e3acd005a2f3d136525cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc0e3acd005a2f3d136525cc',
#        'width': 64}],
#      'name': 'Honeymoon',
#      'release_date': '2020-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:1PAsUJFVKxmdofGFsFU3Df'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#       'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#       'id': '2vnB6tuQMaQpORiRdvXF9H',
#       'name': 'Beach Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#     'available_markets': ['AU', 'NZ'],
#     'disc_number': 1,
#     'duration_ms': 137600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQE91600054'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/589Lt4lVKxd1qXOrPaAHkB'},
#     'href': 'https://api.spotify.com/v1/tracks/589Lt4lVKxd1qXOrPaAHkB',
#     'id': '589Lt4lVKxd1qXOrPaAHkB',
#     'is_local': False,
#     'name': 'Cloud 9',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2c08f232a2c54cf22681dde0450c08d08e224c1c?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:589Lt4lVKxd1qXOrPaAHkB'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-02-19T05:00:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P2rwRBgIN450RaJxdjYdA'},
#        'href': 'https://api.spotify.com/v1/artists/5P2rwRBgIN450RaJxdjYdA',
#        'id': '5P2rwRBgIN450RaJxdjYdA',
#        'name': 'Kardinal Offishall',
#        'type': 'artist',
#        'uri': 'spotify:artist:5P2rwRBgIN450RaJxdjYdA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MN',
#       'MT',
#       'MU',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'SZ',
#       'TD',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'UG',
#       'US',
#       'UZ',
#       'VN',
#       'XK',
#       'ZA',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mvT7q9PuuBWZcVyUnZP8e'},
#      'href': 'https://api.spotify.com/v1/albums/4mvT7q9PuuBWZcVyUnZP8e',
#      'id': '4mvT7q9PuuBWZcVyUnZP8e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cedc24abc2e757d13b386d1e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cedc24abc2e757d13b386d1e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cedc24abc2e757d13b386d1e',
#        'width': 64}],
#      'name': 'Not 4 Sale',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:4mvT7q9PuuBWZcVyUnZP8e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P2rwRBgIN450RaJxdjYdA'},
#       'href': 'https://api.spotify.com/v1/artists/5P2rwRBgIN450RaJxdjYdA',
#       'id': '5P2rwRBgIN450RaJxdjYdA',
#       'name': 'Kardinal Offishall',
#       'type': 'artist',
#       'uri': 'spotify:artist:5P2rwRBgIN450RaJxdjYdA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#       'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#       'id': '0z4gvV4rjIZ9wHck67ucSV',
#       'name': 'Akon',
#       'type': 'artist',
#       'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MN',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'SZ',
#      'TD',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'UG',
#      'US',
#      'UZ',
#      'VN',
#      'XK',
# ...
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 165600,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USLD90810521'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qgZvYWLIqDn0tXimF8gPa'},
#     'href': 'https://api.spotify.com/v1/tracks/0qgZvYWLIqDn0tXimF8gPa',
#     'id': '0qgZvYWLIqDn0tXimF8gPa',
#     'is_local': False,
#     'name': 'dirty laundry',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f84fc3a6fe1fc536d976ca57edb27971c09bc1b4?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0qgZvYWLIqDn0tXimF8gPa'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-03-01T03:06:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wHeZY93Ede0g1jXaWsiFS'},
#        'href': 'https://api.spotify.com/v1/artists/0wHeZY93Ede0g1jXaWsiFS',
#        'id': '0wHeZY93Ede0g1jXaWsiFS',
#        'name': 'LPB Poody',
#        'type': 'artist',
#        'uri': 'spotify:artist:0wHeZY93Ede0g1jXaWsiFS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2XtDT9YT729iLxWjuTMtrR'},
#      'href': 'https://api.spotify.com/v1/albums/2XtDT9YT729iLxWjuTMtrR',
#      'id': '2XtDT9YT729iLxWjuTMtrR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb05db2aafb810d71d918a55',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb05db2aafb810d71d918a55',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb05db2aafb810d71d918a55',
#        'width': 64}],
#      'name': 'Batman',
#      'release_date': '2021-02-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2XtDT9YT729iLxWjuTMtrR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wHeZY93Ede0g1jXaWsiFS'},
#       'href': 'https://api.spotify.com/v1/artists/0wHeZY93Ede0g1jXaWsiFS',
#       'id': '0wHeZY93Ede0g1jXaWsiFS',
#       'name': 'LPB Poody',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wHeZY93Ede0g1jXaWsiFS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 156431,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72101263'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xMvdOFQaql3EBkHmuh2TK'},
#     'href': 'https://api.spotify.com/v1/tracks/1xMvdOFQaql3EBkHmuh2TK',
#     'id': '1xMvdOFQaql3EBkHmuh2TK',
#     'is_local': False,
#     'name': 'Batman',
#     'popularity': 80,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b476e95fd0ddd7e1997a6148ee91db441b6bc1e7?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1xMvdOFQaql3EBkHmuh2TK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-02-19T05:00:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#        'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#        'id': '0e86yPdC41PGRkLp2Q1Bph',
#        'name': 'Mother Mother',
#        'type': 'artist',
#        'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#      'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#      'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#        'width': 64}],
#      'name': 'O My Heart',
#      'release_date': '2008-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#       'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#       'id': '0e86yPdC41PGRkLp2Q1Bph',
#       'name': 'Mother Mother',
#       'type': 'artist',
#       'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 181680,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAL450882108'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2kS6td1yvmpNgZTt1q5pQq'},
#     'href': 'https://api.spotify.com/v1/tracks/2kS6td1yvmpNgZTt1q5pQq',
#     'id': '2kS6td1yvmpNgZTt1q5pQq',
#     'is_local': False,
#     'name': 'Hayloft',
#     'popularity': 86,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f7ea49e6d92e99190acff02665f2ce2b6de1da99?cid=774b29d4f13844c495f206cafdad9c86',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2kS6td1yvmpNgZTt1q5pQq'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2L0iB23Enbq/tracks?offset=50&limit=50',
#  'offset': 0,
#  'previous': None,
#  'total': 101}

# %%
playlist_items = playlist_api_response['items']

# %%
playlist_items
# Out:
# [{'added_at': '2021-03-29T23:10:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#       'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#       'id': '5VZn4mB8pS40aE0kujdX2Y',
#       'name': 'Chloe George',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6W4tUP2tcem0izGTVzxx5g'},
#     'href': 'https://api.spotify.com/v1/albums/6W4tUP2tcem0izGTVzxx5g',
#     'id': '6W4tUP2tcem0izGTVzxx5g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735b6327459f5454a084d656f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025b6327459f5454a084d656f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515b6327459f5454a084d656f0',
#       'width': 64}],
#     'name': 'ghost town (voice memo)',
#     'release_date': '2021-03-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6W4tUP2tcem0izGTVzxx5g'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#      'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#      'id': '5VZn4mB8pS40aE0kujdX2Y',
#      'name': 'Chloe George',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 137250,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72104942'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0PKAijroHpnEtdY20bkGdr'},
#    'href': 'https://api.spotify.com/v1/tracks/0PKAijroHpnEtdY20bkGdr',
#    'id': '0PKAijroHpnEtdY20bkGdr',
#    'is_local': False,
#    'name': 'ghost town (voice memo)',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1dc760d2bfd12adfe1d5090dc48f35161242799d?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0PKAijroHpnEtdY20bkGdr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-03-21T02:01:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#       'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#       'id': '2KsP6tYLJlTBvSUxnwlVWa',
#       'name': 'Mike Posner',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2nnIlWcriIqcJtjduWcTRl'},
#     'href': 'https://api.spotify.com/v1/albums/2nnIlWcriIqcJtjduWcTRl',
#     'id': '2nnIlWcriIqcJtjduWcTRl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a98ac59b1f31230990d941a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a98ac59b1f31230990d941a2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a98ac59b1f31230990d941a2',
#       'width': 64}],
#     'name': '31 Minutes to Takeoff',
#     'release_date': '2010-08-09',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2nnIlWcriIqcJtjduWcTRl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#      'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#      'id': '2KsP6tYLJlTBvSUxnwlVWa',
#      'name': 'Mike Posner',
#      'type': 'artist',
#      'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 196813,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJAY1000077'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6jg5SRvdGxvJ0DzNV0UqEK'},
#    'href': 'https://api.spotify.com/v1/tracks/6jg5SRvdGxvJ0DzNV0UqEK',
#    'id': '6jg5SRvdGxvJ0DzNV0UqEK',
#    'is_local': False,
#    'name': "Please Don't Go",
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/66706c36ab06b681bc2b5d269f7387ec0110e16f?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6jg5SRvdGxvJ0DzNV0UqEK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-01T02:35:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#       'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#       'id': '7jVv8c5Fj3E9VhNjxT4snq',
#       'name': 'Lil Nas X',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5iZytG7j5DDp9RlsmkGI97'},
#     'href': 'https://api.spotify.com/v1/albums/5iZytG7j5DDp9RlsmkGI97',
#     'id': '5iZytG7j5DDp9RlsmkGI97',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ddb9cf14094fa5b3f8683b14',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ddb9cf14094fa5b3f8683b14',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ddb9cf14094fa5b3f8683b14',
#       'width': 64}],
#     'name': 'MONTERO (Call Me By Your Name)',
#     'release_date': '2021-03-26',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5iZytG7j5DDp9RlsmkGI97'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#      'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#      'id': '7jVv8c5Fj3E9VhNjxT4snq',
#      'name': 'Lil Nas X',
#      'type': 'artist',
#      'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 137875,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSM12100531'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3BZEcbdtXQSo7OrvKRJ6mb'},
#    'href': 'https://api.spotify.com/v1/tracks/3BZEcbdtXQSo7OrvKRJ6mb',
#    'id': '3BZEcbdtXQSo7OrvKRJ6mb',
#    'is_local': False,
#    'name': 'MONTERO (Call Me By Your Name)',
#    'popularity': 99,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3BZEcbdtXQSo7OrvKRJ6mb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-03-05T00:21:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IJczjB0fJ04gs4uvP0Fli'},
#       'href': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli',
#       'id': '4IJczjB0fJ04gs4uvP0Fli',
#       'name': 'Gym Class Heroes',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IJczjB0fJ04gs4uvP0Fli'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Ug3M4a8wAEebndVIF65fX'},
#     'href': 'https://api.spotify.com/v1/albums/4Ug3M4a8wAEebndVIF65fX',
#     'id': '4Ug3M4a8wAEebndVIF65fX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f335d8387c3658831112f914',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f335d8387c3658831112f914',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f335d8387c3658831112f914',
#       'width': 64}],
#     'name': 'The Papercut Chronicles',
#     'release_date': '2005-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:4Ug3M4a8wAEebndVIF65fX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IJczjB0fJ04gs4uvP0Fli'},
#      'href': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli',
#      'id': '4IJczjB0fJ04gs4uvP0Fli',
#      'name': 'Gym Class Heroes',
#      'type': 'artist',
#      'uri': 'spotify:artist:4IJczjB0fJ04gs4uvP0Fli'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 243773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US56V0407211'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Lhdl74nwwVGOE2Gv35QuK'},
#    'href': 'https://api.spotify.com/v1/tracks/2Lhdl74nwwVGOE2Gv35QuK',
#    'id': '2Lhdl74nwwVGOE2Gv35QuK',
#    'is_local': False,
#    'name': "Cupid's Chokehold / Breakfast in America",
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/aa1ffc19b8b6b8cea5446b81b5ec3d1254231c94?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:2Lhdl74nwwVGOE2Gv35QuK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-03-30T20:23:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'BN',
#      'BO',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'KH',
#      'KR',
#      'LA',
#      'MO',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PY',
#      'SG',
#      'SR',
#      'SV',
#      'TH',
#      'TL',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1uyf3l2d4XYwiEqAb7t7fX'},
#     'href': 'https://api.spotify.com/v1/albums/1uyf3l2d4XYwiEqAb7t7fX',
#     'id': '1uyf3l2d4XYwiEqAb7t7fX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27378c6c624a95d1bd02ba1fa02',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0278c6c624a95d1bd02ba1fa02',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485178c6c624a95d1bd02ba1fa02',
#       'width': 64}],
#     'name': 'Doo-Wops & Hooligans',
#     'release_date': '2010-10-05',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1uyf3l2d4XYwiEqAb7t7fX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'available_markets': ['AR',
#     'AU',
#     'BN',
#     'BO',
#     'BZ',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'DO',
#     'EC',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'ID',
#     'IN',
#     'KH',
#     'KR',
#     'LA',
#     'MO',
#     'MX',
#     'MY',
#     'NI',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PY',
#     'SG',
#     'SR',
#     'SV',
#     'TH',
#     'TL',
#     'TW',
#     'US',
#     'UY',
#     'VN'],
#    'disc_number': 1,
#    'duration_ms': 217866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21001985'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/161DnLWsx1i3u1JT05lzqU'},
#    'href': 'https://api.spotify.com/v1/tracks/161DnLWsx1i3u1JT05lzqU',
#    'id': '161DnLWsx1i3u1JT05lzqU',
#    'is_local': False,
#    'name': 'Talking to the Moon',
#    'popularity': 83,
#    'preview_url': 'https://p.scdn.co/mp3-preview/97de5b6d487f491cddfb427c1612f45f5b3c9388?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:161DnLWsx1i3u1JT05lzqU'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-02-19T05:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uU7g3DNSbsu0QjSEqZtEd'},
#       'href': 'https://api.spotify.com/v1/artists/1uU7g3DNSbsu0QjSEqZtEd',
#       'id': '1uU7g3DNSbsu0QjSEqZtEd',
#       'name': 'Masked Wolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uU7g3DNSbsu0QjSEqZtEd'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/023KmMyB2DNZR3V8YKoET9'},
#     'href': 'https://api.spotify.com/v1/albums/023KmMyB2DNZR3V8YKoET9',
#     'id': '023KmMyB2DNZR3V8YKoET9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273214ace0e5ba30b74d19efb19',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02214ace0e5ba30b74d19efb19',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851214ace0e5ba30b74d19efb19',
#       'width': 64}],
#     'name': 'Astronaut In The Ocean',
#     'release_date': '2019-06-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:023KmMyB2DNZR3V8YKoET9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uU7g3DNSbsu0QjSEqZtEd'},
#      'href': 'https://api.spotify.com/v1/artists/1uU7g3DNSbsu0QjSEqZtEd',
#      'id': '1uU7g3DNSbsu0QjSEqZtEd',
#      'name': 'Masked Wolf',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uU7g3DNSbsu0QjSEqZtEd'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 132780,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUFXV1900105'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0jdso14vaFnpRazMLEZovF'},
#    'href': 'https://api.spotify.com/v1/tracks/0jdso14vaFnpRazMLEZovF',
#    'id': '0jdso14vaFnpRazMLEZovF',
#    'is_local': False,
#    'name': 'Astronaut In The Ocean',
#    'popularity': 56,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0jdso14vaFnpRazMLEZovF'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-05T21:41:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#       'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#       'id': '1LZEQNv7sE11VDY3SdxQeN',
#       'name': 'Bee Gees',
#       'type': 'artist',
#       'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vAhQeeWkSjVn0p5GAaLBx'},
#     'href': 'https://api.spotify.com/v1/albums/4vAhQeeWkSjVn0p5GAaLBx',
#     'id': '4vAhQeeWkSjVn0p5GAaLBx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273324045726c4b0deb6cb7c875',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02324045726c4b0deb6cb7c875',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851324045726c4b0deb6cb7c875',
#       'width': 64}],
#     'name': 'How Can You Mend A Broken Heart',
#     'release_date': '2020-11-20',
#     'release_date_precision': 'day',
#     'total_tracks': 25,
#     'type': 'album',
#     'uri': 'spotify:album:4vAhQeeWkSjVn0p5GAaLBx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#      'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#      'id': '1LZEQNv7sE11VDY3SdxQeN',
#      'name': 'Bee Gees',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'}],
#    'available_markets': ['AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GH',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'KW',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 196213,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLF057790033'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2cX2coZS1PYBfPs8wgbdWE'},
#    'href': 'https://api.spotify.com/v1/tracks/2cX2coZS1PYBfPs8wgbdWE',
#    'id': '2cX2coZS1PYBfPs8wgbdWE',
#    'is_local': False,
#    'name': 'More Than A Woman - From "Saturday Night Fever" Soundtrack',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0396e55e0afb98e464697b7e749b4b40d3a69363?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:2cX2coZS1PYBfPs8wgbdWE'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-05T00:47:48Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#     'href': 'https://api.spotify.com/v1/albums/5dGWwsZ9iB2Xc3UKR0gif2',
#     'id': '5dGWwsZ9iB2Xc3UKR0gif2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6f407c7f3a0ec98845e4431',
#       'width': 64}],
#     'name': 'Justice',
#     'release_date': '2021-03-19',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5dGWwsZ9iB2Xc3UKR0gif2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#      'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#      'id': '20wkVLutqVOYrc0kxFs7rA',
#      'name': 'Daniel Caesar',
#      'type': 'artist',
#      'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#      'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#      'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#      'name': 'Giveon',
#      'type': 'artist',
#      'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 198081,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72102636'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI'},
#    'href': 'https://api.spotify.com/v1/tracks/4iJyoBOLtHqaGxP12qzhQI',
#    'id': '4iJyoBOLtHqaGxP12qzhQI',
#    'is_local': False,
#    'name': 'Peaches (feat. Daniel Caesar & Giveon)',
#    'popularity': 100,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2d914ef1e42235bd50ba4f1c08f84d84ebb0bebc?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:4iJyoBOLtHqaGxP12qzhQI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-03-15T21:46:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#       'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#       'id': '2vnB6tuQMaQpORiRdvXF9H',
#       'name': 'Beach Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#     'available_markets': ['AU', 'NZ'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1PAsUJFVKxmdofGFsFU3Df'},
#     'href': 'https://api.spotify.com/v1/albums/1PAsUJFVKxmdofGFsFU3Df',
#     'id': '1PAsUJFVKxmdofGFsFU3Df',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bc0e3acd005a2f3d136525cc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bc0e3acd005a2f3d136525cc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bc0e3acd005a2f3d136525cc',
#       'width': 64}],
#     'name': 'Honeymoon',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:1PAsUJFVKxmdofGFsFU3Df'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#      'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#      'id': '2vnB6tuQMaQpORiRdvXF9H',
#      'name': 'Beach Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#    'available_markets': ['AU', 'NZ'],
#    'disc_number': 1,
#    'duration_ms': 137600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQE91600054'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/589Lt4lVKxd1qXOrPaAHkB'},
#    'href': 'https://api.spotify.com/v1/tracks/589Lt4lVKxd1qXOrPaAHkB',
#    'id': '589Lt4lVKxd1qXOrPaAHkB',
#    'is_local': False,
#    'name': 'Cloud 9',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2c08f232a2c54cf22681dde0450c08d08e224c1c?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:589Lt4lVKxd1qXOrPaAHkB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-02-19T05:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P2rwRBgIN450RaJxdjYdA'},
#       'href': 'https://api.spotify.com/v1/artists/5P2rwRBgIN450RaJxdjYdA',
#       'id': '5P2rwRBgIN450RaJxdjYdA',
#       'name': 'Kardinal Offishall',
#       'type': 'artist',
#       'uri': 'spotify:artist:5P2rwRBgIN450RaJxdjYdA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MN',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'SZ',
#      'TD',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'UG',
#      'US',
#      'UZ',
#      'VN',
#      'XK',
#      'ZA',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4mvT7q9PuuBWZcVyUnZP8e'},
#     'href': 'https://api.spotify.com/v1/albums/4mvT7q9PuuBWZcVyUnZP8e',
#     'id': '4mvT7q9PuuBWZcVyUnZP8e',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cedc24abc2e757d13b386d1e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cedc24abc2e757d13b386d1e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cedc24abc2e757d13b386d1e',
#       'width': 64}],
#     'name': 'Not 4 Sale',
#     'release_date': '2008-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:4mvT7q9PuuBWZcVyUnZP8e'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P2rwRBgIN450RaJxdjYdA'},
#      'href': 'https://api.spotify.com/v1/artists/5P2rwRBgIN450RaJxdjYdA',
#      'id': '5P2rwRBgIN450RaJxdjYdA',
#      'name': 'Kardinal Offishall',
#      'type': 'artist',
#      'uri': 'spotify:artist:5P2rwRBgIN450RaJxdjYdA'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#      'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#      'id': '0z4gvV4rjIZ9wHck67ucSV',
#      'name': 'Akon',
#      'type': 'artist',
#      'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AM',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BS',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LI',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MN',
#     'MT',
#     'MU',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'SZ',
#     'TD',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'UG',
#     'US',
#     'UZ',
#     'VN',
#     'XK',
#     'ZA',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 246053,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM70830921'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4NOZ35Dhucr6UlVyLOtktd'},
#    'href': 'https://api.spotify.com/v1/tracks/4NOZ35Dhucr6UlVyLOtktd',
#    'id': '4NOZ35Dhucr6UlVyLOtktd',
#    'is_local': False,
#    'name': 'Dangerous',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/324266f507f3b1e102f5a91b76d99a236da436b7?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4NOZ35Dhucr6UlVyLOtktd'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-03-03T23:07:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': ['AD',
#      'AG',
#      'AM',
#      'AR',
#      'AU',
#      'AZ',
#      'BB',
#      'BD',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DJ',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'GA',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KZ',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LV',
#      'MC',
#      'MD',
#      'MG',
#      'ML',
#      'MN',
#      'MO',
#      'MT',
#      'MU',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RU',
#      'RW',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TR',
#      'TT',
# ...
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1TkwzY3l4LqAfrQwBAx45Q'},
#     'href': 'https://api.spotify.com/v1/albums/1TkwzY3l4LqAfrQwBAx45Q',
#     'id': '1TkwzY3l4LqAfrQwBAx45Q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf33fdea7b0ff3c71b6faf75',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf33fdea7b0ff3c71b6faf75',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf33fdea7b0ff3c71b6faf75',
#       'width': 64}],
#     'name': 'deadroses',
#     'release_date': '2015-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1TkwzY3l4LqAfrQwBAx45Q'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#      'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#      'id': '2cFrymmkijnjDg9SS92EPM',
#      'name': 'blackbear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 165600,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USLD90810521'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0qgZvYWLIqDn0tXimF8gPa'},
#    'href': 'https://api.spotify.com/v1/tracks/0qgZvYWLIqDn0tXimF8gPa',
#    'id': '0qgZvYWLIqDn0tXimF8gPa',
#    'is_local': False,
#    'name': 'dirty laundry',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f84fc3a6fe1fc536d976ca57edb27971c09bc1b4?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:0qgZvYWLIqDn0tXimF8gPa'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-03-01T03:06:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wHeZY93Ede0g1jXaWsiFS'},
#       'href': 'https://api.spotify.com/v1/artists/0wHeZY93Ede0g1jXaWsiFS',
#       'id': '0wHeZY93Ede0g1jXaWsiFS',
#       'name': 'LPB Poody',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wHeZY93Ede0g1jXaWsiFS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2XtDT9YT729iLxWjuTMtrR'},
#     'href': 'https://api.spotify.com/v1/albums/2XtDT9YT729iLxWjuTMtrR',
#     'id': '2XtDT9YT729iLxWjuTMtrR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eb05db2aafb810d71d918a55',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eb05db2aafb810d71d918a55',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eb05db2aafb810d71d918a55',
#       'width': 64}],
#     'name': 'Batman',
#     'release_date': '2021-02-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2XtDT9YT729iLxWjuTMtrR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wHeZY93Ede0g1jXaWsiFS'},
#      'href': 'https://api.spotify.com/v1/artists/0wHeZY93Ede0g1jXaWsiFS',
#      'id': '0wHeZY93Ede0g1jXaWsiFS',
#      'name': 'LPB Poody',
#      'type': 'artist',
#      'uri': 'spotify:artist:0wHeZY93Ede0g1jXaWsiFS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 156431,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72101263'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1xMvdOFQaql3EBkHmuh2TK'},
#    'href': 'https://api.spotify.com/v1/tracks/1xMvdOFQaql3EBkHmuh2TK',
#    'id': '1xMvdOFQaql3EBkHmuh2TK',
#    'is_local': False,
#    'name': 'Batman',
#    'popularity': 80,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b476e95fd0ddd7e1997a6148ee91db441b6bc1e7?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1xMvdOFQaql3EBkHmuh2TK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-02-19T05:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#       'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#       'id': '0e86yPdC41PGRkLp2Q1Bph',
#       'name': 'Mother Mother',
#       'type': 'artist',
#       'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#     'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#     'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#       'width': 64}],
#     'name': 'O My Heart',
#     'release_date': '2008-09-23',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#      'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#      'id': '0e86yPdC41PGRkLp2Q1Bph',
#      'name': 'Mother Mother',
#      'type': 'artist',
#      'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 181680,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAL450882108'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2kS6td1yvmpNgZTt1q5pQq'},
#    'href': 'https://api.spotify.com/v1/tracks/2kS6td1yvmpNgZTt1q5pQq',
#    'id': '2kS6td1yvmpNgZTt1q5pQq',
#    'is_local': False,
#    'name': 'Hayloft',
#    'popularity': 86,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f7ea49e6d92e99190acff02665f2ce2b6de1da99?cid=774b29d4f13844c495f206cafdad9c86',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:2kS6td1yvmpNgZTt1q5pQq'},
#   'video_thumbnail': {'url': None}}]

# %%
track_list_ids = ''
artists_list_ids = ''

# %%
for index, item in enumerate(playlist_items):
    print(index)

    print("track_id = " + item['track']['id'])
    track_list_ids += item['track']['id'] + ','

    print("artist_id = " + item['track']['artists'][0]['id'])
  
    if item['track']['artists'][0]['id'] not in artists_list_ids: 
        artists_list_ids += item['track']['artists'][0]['id'] + ','
# Out:
# 0
# track_id = 0PKAijroHpnEtdY20bkGdr
# artist_id = 5VZn4mB8pS40aE0kujdX2Y
# 1
# track_id = 6jg5SRvdGxvJ0DzNV0UqEK
# artist_id = 2KsP6tYLJlTBvSUxnwlVWa
# 2
# track_id = 3BZEcbdtXQSo7OrvKRJ6mb
# artist_id = 7jVv8c5Fj3E9VhNjxT4snq
# 3
# track_id = 2Lhdl74nwwVGOE2Gv35QuK
# artist_id = 4IJczjB0fJ04gs4uvP0Fli
# 4
# track_id = 161DnLWsx1i3u1JT05lzqU
# artist_id = 0du5cEVh5yTK9QJze8zA0C
# 5
# track_id = 0jdso14vaFnpRazMLEZovF
# artist_id = 1uU7g3DNSbsu0QjSEqZtEd
# 6
# track_id = 2cX2coZS1PYBfPs8wgbdWE
# artist_id = 1LZEQNv7sE11VDY3SdxQeN
# 7
# track_id = 4iJyoBOLtHqaGxP12qzhQI
# artist_id = 1uNFoZAHBGtllmzznpCI3s
# 8
# track_id = 589Lt4lVKxd1qXOrPaAHkB
# artist_id = 2vnB6tuQMaQpORiRdvXF9H
# 9
# track_id = 4NOZ35Dhucr6UlVyLOtktd
# artist_id = 5P2rwRBgIN450RaJxdjYdA
# 10
# track_id = 5WQQIDU3HRaMyPkob8mpFb
# artist_id = 5pKCCKE2ajJHZ9KAiaK11H
# 11
# track_id = 2BKyXCkxhZRGwREqZacJ9M
# artist_id = 6GMYJwaziB4ekv1Y6wCDWS
# 12
# track_id = 3qGHAKgjQruzj6doKkyEb5
# artist_id = 25uiPmTg16RbhZWAqwLBy5
# 13
# track_id = 0TCmhnbMpw5zwPsTvlXTJi
# artist_id = 1WgXqy2Dd70QQOU7Ay074N
# 14
# track_id = 1M4OcYkxAtu3ErzSgDEfoi
# artist_id = 4kYSro6naA4h99UJvo89HB
# 15
# track_id = 6tDDoYIxWvMLTdKpjFkc1B
# artist_id = 1U1el3k54VvEUzo3ybLPlM
# 16
# track_id = 3FxPbp05KjMBa4HbhAJTH0
# artist_id = 4b19vuzlDcNdU4quI7L6sW
# 17
# track_id = 60PAzFNW3vAiAiVK6DRJfB
# artist_id = 0fA0VVWsXO9YnASrzqfmYu
# 18
# track_id = 1j3SdMJfeRJXycCp50boYE
# artist_id = 4E2rKHVDssGJm2SCDOMMJB
# 19
# track_id = 1yLTcitjbEJr7a4jyDB0Lz
# artist_id = 7kRrkUEPgO3TRfAi7Gsw2i
# 20
# track_id = 7lgvGRC1gN0JGgY9VGXsQT
# artist_id = 6GkJh85o22LfD2vgL9DP6f
# 21
# track_id = 6IbnUaczZBT34DhaD6S18F
# artist_id = 6CwfuxIqcltXDGjfZsMd9A
# 22
# track_id = 11ZulcYY4lowvcQm4oe3VJ
# artist_id = 3PyJHH2wyfQK3WZrk9rpmP
# 23
# track_id = 4wH4dJgrsxONID6KS2tDQM
# artist_id = 2jw70GZXlAI8QzWeY2bgRc
# 24
# track_id = 6NWdgyVsjp2bJ11PToXCr1
# artist_id = 2SXhbucehn00OBVKhzxDyM
# 25
# track_id = 1zVMJGPMWKmD4cjTTyf68y
# artist_id = 54R6Y0I7jGUCveDTtI21nb
# 26
# track_id = 1ko2lVN0vKGUl9zrU0qSlT
# artist_id = 05YVYeV4HxYp5rrWalvuE1
# 27
# track_id = 2tznHmp70DxMyr2XhWLOW0
# artist_id = 26T3LtbuGT1Fu9m0eRq5X3
# 28
# track_id = 1uH1Nd8vet2uoZSDFSDwbh
# artist_id = 3aQeKQSyrW4qWr35idm0cy
# 29
# track_id = 18V1UiYRvWYwn01CRDbbuR
# artist_id = 15K8w0bfYieOr55vhSMgJN
# 30
# track_id = 5s2zbxZI4Ym5LTKwjZHS2V
# artist_id = 3XxNRirzbjfLdDli06zMaB
# 31
# track_id = 2QjOHCTQ1Jl3zawyYOpxh6
# artist_id = 77SW9BnxLY8rJ0RciFqkHh
# 32
# track_id = 2HYvkdq6lpFXkVz9Tfqi8r
# artist_id = 1gPhS1zisyXr5dHTYZyiMe
# 33
# track_id = 4pBhTGnL5N5KqsyqU58jee
# artist_id = 6DdbeAeBlrYj8bNToZv4TY
# 34
# track_id = 4KrhaZm4JRkNO4HRdLvJIG
# artist_id = 3JG79Z23wJN9Q5PTPpDAEV
# 35
# track_id = 4jY3GWEqlrTALvVE1j7VHI
# artist_id = 63kE1M6nlHBGwRttAc4Q6Z
# 36
# track_id = 60ynsPSSKe6O3sfwRnIBRf
# artist_id = 5cj0lLjcoR7YOSnhnX0Po5
# 37
# track_id = 7CCCX50zGHMTuHsyKQy03l
# artist_id = 0bBz5bRBkExaej2HxtVfCw
# 38
# track_id = 48q0vSHcJdhK3IiXH8C5WJ
# artist_id = 7Ln80lUS6He07XvHI8qqHH
# 39
# track_id = 3EikYy40GMSp8l5mDV6IQo
# artist_id = 2rhFzFmezpnW82MNqEKVry
# 40
# track_id = 4mCf3vQf7z0Yseo0RxAi3V
# artist_id = 5pKCCKE2ajJHZ9KAiaK11H
# 41
# track_id = 0O45fw2L5vsWpdsOdXwNAR
# artist_id = 31TPClRtHm23RisEBtV3X7
# 42
# track_id = 7L6G0wpIUiPXuvoo7qhb06
# artist_id = 2YOYua8FpudSEiB9s88IgQ
# 43
# track_id = 2gam98EZKrF9XuOkU13ApN
# artist_id = 2jw70GZXlAI8QzWeY2bgRc
# 44
# track_id = 4aarlAfLKVCTxUDNgbwhjH
# artist_id = 181bsRPaVXVlUKXrxwZfHK
# 45
# track_id = 5hChuUMe5iHfjkXgzj1D4b
# artist_id = 4NqH3V7GS0Igs1VyGMXEi8
# 46
# track_id = 3iw6V4LH7yPj1ESORX9RIN
# artist_id = 1PKErrAhYFdfrDymGHRQRo
# 47
# track_id = 0qgZvYWLIqDn0tXimF8gPa
# artist_id = 2cFrymmkijnjDg9SS92EPM
# 48
# track_id = 1xMvdOFQaql3EBkHmuh2TK
# artist_id = 0wHeZY93Ede0g1jXaWsiFS
# 49
# track_id = 2kS6td1yvmpNgZTt1q5pQq
# artist_id = 0e86yPdC41PGRkLp2Q1Bph

# %%
track_list_ids = track_list_ids[0:-1]
artists_list_ids = artists_list_ids[0:-1]

# %%
track_features_endpoint_url = f'https://api.spotify.com/v1/audio-features/'

params = {'ids':track_list_ids}

track_features_api_request = requests.get(track_features_endpoint_url, headers = headers, params= params )

# %%
track_features_api_response = json.loads(track_features_api_request.text)

# %%
track_features_api_response['audio_features']
# Out:
# [{'danceability': 0.471,
#   'energy': 0.229,
#   'key': 8,
#   'loudness': -6.504,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'acousticness': 0.953,
#   'instrumentalness': 0,
#   'liveness': 0.0909,
#   'valence': 0.358,
#   'tempo': 68.41,
#   'type': 'audio_features',
#   'id': '0PKAijroHpnEtdY20bkGdr',
#   'uri': 'spotify:track:0PKAijroHpnEtdY20bkGdr',
#   'track_href': 'https://api.spotify.com/v1/tracks/0PKAijroHpnEtdY20bkGdr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PKAijroHpnEtdY20bkGdr',
#   'duration_ms': 137250,
#   'time_signature': 3},
#  {'danceability': 0.699,
#   'energy': 0.882,
#   'key': 4,
#   'loudness': -3.896,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.00296,
#   'instrumentalness': 0.0544,
#   'liveness': 0.13,
#   'valence': 0.657,
#   'tempo': 120.016,
#   'type': 'audio_features',
#   'id': '6jg5SRvdGxvJ0DzNV0UqEK',
#   'uri': 'spotify:track:6jg5SRvdGxvJ0DzNV0UqEK',
#   'track_href': 'https://api.spotify.com/v1/tracks/6jg5SRvdGxvJ0DzNV0UqEK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6jg5SRvdGxvJ0DzNV0UqEK',
#   'duration_ms': 196813,
#   'time_signature': 4},
#  {'danceability': 0.61,
#   'energy': 0.508,
#   'key': 8,
#   'loudness': -6.682,
#   'mode': 0,
#   'speechiness': 0.152,
#   'acousticness': 0.297,
#   'instrumentalness': 0,
#   'liveness': 0.384,
#   'valence': 0.758,
#   'tempo': 178.818,
#   'type': 'audio_features',
#   'id': '3BZEcbdtXQSo7OrvKRJ6mb',
#   'uri': 'spotify:track:3BZEcbdtXQSo7OrvKRJ6mb',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BZEcbdtXQSo7OrvKRJ6mb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BZEcbdtXQSo7OrvKRJ6mb',
#   'duration_ms': 137876,
#   'time_signature': 4},
#  {'danceability': 0.72,
#   'energy': 0.744,
#   'key': 1,
#   'loudness': -6.938,
#   'mode': 0,
#   'speechiness': 0.12,
#   'acousticness': 0.237,
#   'instrumentalness': 0,
#   'liveness': 0.255,
#   'valence': 0.619,
#   'tempo': 78.953,
#   'type': 'audio_features',
#   'id': '2Lhdl74nwwVGOE2Gv35QuK',
#   'uri': 'spotify:track:2Lhdl74nwwVGOE2Gv35QuK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Lhdl74nwwVGOE2Gv35QuK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Lhdl74nwwVGOE2Gv35QuK',
#   'duration_ms': 243773,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.606,
#   'key': 1,
#   'loudness': -4.754,
#   'mode': 0,
#   'speechiness': 0.0301,
#   'acousticness': 0.512,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.065,
#   'tempo': 145.837,
#   'type': 'audio_features',
#   'id': '161DnLWsx1i3u1JT05lzqU',
#   'uri': 'spotify:track:161DnLWsx1i3u1JT05lzqU',
#   'track_href': 'https://api.spotify.com/v1/tracks/161DnLWsx1i3u1JT05lzqU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/161DnLWsx1i3u1JT05lzqU',
#   'duration_ms': 217867,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.695,
#   'key': 4,
#   'loudness': -6.865,
#   'mode': 0,
#   'speechiness': 0.0913,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.472,
#   'tempo': 149.996,
#   'type': 'audio_features',
#   'id': '0jdso14vaFnpRazMLEZovF',
#   'uri': 'spotify:track:0jdso14vaFnpRazMLEZovF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0jdso14vaFnpRazMLEZovF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jdso14vaFnpRazMLEZovF',
#   'duration_ms': 132780,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.703,
#   'key': 7,
#   'loudness': -6.24,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.175,
#   'instrumentalness': 8.4e-05,
#   'liveness': 0.571,
#   'valence': 0.673,
#   'tempo': 106.164,
#   'type': 'audio_features',
#   'id': '2cX2coZS1PYBfPs8wgbdWE',
#   'uri': 'spotify:track:2cX2coZS1PYBfPs8wgbdWE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2cX2coZS1PYBfPs8wgbdWE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2cX2coZS1PYBfPs8wgbdWE',
#   'duration_ms': 196213,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.696,
#   'key': 0,
#   'loudness': -6.181,
#   'mode': 1,
#   'speechiness': 0.119,
#   'acousticness': 0.321,
#   'instrumentalness': 0,
#   'liveness': 0.42,
#   'valence': 0.464,
#   'tempo': 90.03,
#   'type': 'audio_features',
#   'id': '4iJyoBOLtHqaGxP12qzhQI',
#   'uri': 'spotify:track:4iJyoBOLtHqaGxP12qzhQI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4iJyoBOLtHqaGxP12qzhQI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4iJyoBOLtHqaGxP12qzhQI',
#   'duration_ms': 198082,
#   'time_signature': 4},
#  {'danceability': 0.627,
#   'energy': 0.935,
#   'key': 4,
#   'loudness': -3.257,
#   'mode': 1,
#   'speechiness': 0.0495,
#   'acousticness': 0.00145,
#   'instrumentalness': 1.72e-05,
#   'liveness': 0.335,
#   'valence': 0.903,
#   'tempo': 80.986,
#   'type': 'audio_features',
#   'id': '589Lt4lVKxd1qXOrPaAHkB',
#   'uri': 'spotify:track:589Lt4lVKxd1qXOrPaAHkB',
#   'track_href': 'https://api.spotify.com/v1/tracks/589Lt4lVKxd1qXOrPaAHkB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/589Lt4lVKxd1qXOrPaAHkB',
#   'duration_ms': 137601,
#   'time_signature': 4},
#  {'danceability': 0.949,
#   'energy': 0.79,
#   'key': 8,
#   'loudness': -5.957,
#   'mode': 1,
#   'speechiness': 0.0756,
#   'acousticness': 0.00437,
#   'instrumentalness': 0,
#   'liveness': 0.0816,
#   'valence': 0.807,
#   'tempo': 117.002,
#   'type': 'audio_features',
#   'id': '4NOZ35Dhucr6UlVyLOtktd',
#   'uri': 'spotify:track:4NOZ35Dhucr6UlVyLOtktd',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NOZ35Dhucr6UlVyLOtktd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NOZ35Dhucr6UlVyLOtktd',
#   'duration_ms': 246053,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.847,
#   'key': 0,
#   'loudness': -6.34,
#   'mode': 0,
#   'speechiness': 0.0916,
#   'acousticness': 0.00201,
#   'instrumentalness': 0.0204,
#   'liveness': 0.221,
#   'valence': 0.444,
#   'tempo': 127.963,
#   'type': 'audio_features',
#   'id': '5WQQIDU3HRaMyPkob8mpFb',
#   'uri': 'spotify:track:5WQQIDU3HRaMyPkob8mpFb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5WQQIDU3HRaMyPkob8mpFb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WQQIDU3HRaMyPkob8mpFb',
#   'duration_ms': 242680,
#   'time_signature': 4},
#  {'danceability': 0.938,
#   'energy': 0.463,
#   'key': 1,
#   'loudness': -13.124,
#   'mode': 1,
#   'speechiness': 0.479,
#   'acousticness': 0.035,
#   'instrumentalness': 0.00652,
#   'liveness': 0.1,
#   'valence': 0.46,
#   'tempo': 119.878,
#   'type': 'audio_features',
#   'id': '2BKyXCkxhZRGwREqZacJ9M',
#   'uri': 'spotify:track:2BKyXCkxhZRGwREqZacJ9M',
#   'track_href': 'https://api.spotify.com/v1/tracks/2BKyXCkxhZRGwREqZacJ9M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BKyXCkxhZRGwREqZacJ9M',
#   'duration_ms': 111621,
#   'time_signature': 4},
#  {'danceability': 0.504,
#   'energy': 0.711,
#   'key': 9,
#   'loudness': -5.864,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.0585,
#   'instrumentalness': 1.83e-05,
#   'liveness': 0.382,
#   'valence': 0.5,
#   'tempo': 134.824,
#   'type': 'audio_features',
#   'id': '3qGHAKgjQruzj6doKkyEb5',
#   'uri': 'spotify:track:3qGHAKgjQruzj6doKkyEb5',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qGHAKgjQruzj6doKkyEb5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qGHAKgjQruzj6doKkyEb5',
#   'duration_ms': 232933,
#   'time_signature': 4},
#  {'danceability': 0.421,
#   'energy': 0.277,
#   'key': 11,
#   'loudness': -10.34,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.637,
#   'instrumentalness': 7.18e-05,
#   'liveness': 0.103,
#   'valence': 0.13,
#   'tempo': 115.153,
#   'type': 'audio_features',
#   'id': '0TCmhnbMpw5zwPsTvlXTJi',
#   'uri': 'spotify:track:0TCmhnbMpw5zwPsTvlXTJi',
#   'track_href': 'https://api.spotify.com/v1/tracks/0TCmhnbMpw5zwPsTvlXTJi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0TCmhnbMpw5zwPsTvlXTJi',
#   'duration_ms': 248827,
#   'time_signature': 4},
#  {'danceability': 0.868,
#   'energy': 0.795,
#   'key': 11,
#   'loudness': -6.044,
#   'mode': 1,
#   'speechiness': 0.269,
#   'acousticness': 0.0012,
#   'instrumentalness': 0.0193,
#   'liveness': 0.0461,
#   'valence': 0.819,
#   'tempo': 166.0,
#   'type': 'audio_features',
#   'id': '1M4OcYkxAtu3ErzSgDEfoi',
#   'uri': 'spotify:track:1M4OcYkxAtu3ErzSgDEfoi',
#   'track_href': 'https://api.spotify.com/v1/tracks/1M4OcYkxAtu3ErzSgDEfoi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1M4OcYkxAtu3ErzSgDEfoi',
#   'duration_ms': 156945,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.524,
#   'key': 11,
#   'loudness': -9.016,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.203,
#   'valence': 0.553,
#   'tempo': 83.97,
#   'type': 'audio_features',
#   'id': '6tDDoYIxWvMLTdKpjFkc1B',
#   'uri': 'spotify:track:6tDDoYIxWvMLTdKpjFkc1B',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tDDoYIxWvMLTdKpjFkc1B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tDDoYIxWvMLTdKpjFkc1B',
#   'duration_ms': 160191,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.74,
#   'key': 0,
#   'loudness': -6.558,
#   'mode': 1,
#   'speechiness': 0.097,
#   'acousticness': 0.53,
#   'instrumentalness': 7.37e-05,
#   'liveness': 0.0936,
#   'valence': 0.36,
#   'tempo': 97.735,
#   'type': 'audio_features',
#   'id': '3FxPbp05KjMBa4HbhAJTH0',
#   'uri': 'spotify:track:3FxPbp05KjMBa4HbhAJTH0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3FxPbp05KjMBa4HbhAJTH0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FxPbp05KjMBa4HbhAJTH0',
#   'duration_ms': 80118,
#   'time_signature': 4},
#  {'danceability': 0.88,
#   'energy': 0.443,
#   'key': 11,
#   'loudness': -6.359,
#   'mode': 0,
#   'speechiness': 0.0653,
#   'acousticness': 0.462,
#   'instrumentalness': 7.13e-06,
#   'liveness': 0.122,
#   'valence': 0.803,
#   'tempo': 138.018,
#   'type': 'audio_features',
#   'id': '60PAzFNW3vAiAiVK6DRJfB',
#   'uri': 'spotify:track:60PAzFNW3vAiAiVK6DRJfB',
#   'track_href': 'https://api.spotify.com/v1/tracks/60PAzFNW3vAiAiVK6DRJfB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60PAzFNW3vAiAiVK6DRJfB',
#   'duration_ms': 221240,
#   'time_signature': 4},
#  {'danceability': 0.597,
#   'energy': 0.617,
#   'key': 8,
#   'loudness': -7.482,
#   'mode': 0,
#   'speechiness': 0.282,
#   'acousticness': 0.463,
#   'instrumentalness': 0,
#   'liveness': 0.66,
#   'valence': 0.889,
#   'tempo': 97.923,
#   'type': 'audio_features',
#   'id': '1j3SdMJfeRJXycCp50boYE',
#   'uri': 'spotify:track:1j3SdMJfeRJXycCp50boYE',
#   'track_href': 'https://api.spotify.com/v1/tracks/1j3SdMJfeRJXycCp50boYE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1j3SdMJfeRJXycCp50boYE',
#   'duration_ms': 275520,
#   'time_signature': 4},
#  {'danceability': 0.799,
#   'energy': 0.543,
#   'key': 10,
#   'loudness': -6.094,
#   'mode': 0,
#   'speechiness': 0.24,
#   'acousticness': 0.0512,
#   'instrumentalness': 0.0425,
#   'liveness': 0.134,
#   'valence': 0.25,
#   'tempo': 187.906,
#   'type': 'audio_features',
#   'id': '1yLTcitjbEJr7a4jyDB0Lz',
#   'uri': 'spotify:track:1yLTcitjbEJr7a4jyDB0Lz',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yLTcitjbEJr7a4jyDB0Lz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yLTcitjbEJr7a4jyDB0Lz',
#   'duration_ms': 85742,
#   'time_signature': 4},
#  {'danceability': 0.739,
#   'energy': 0.754,
#   'key': 8,
#   'loudness': -5.034,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.0431,
#   'instrumentalness': 0,
#   'liveness': 0.0999,
#   'valence': 0.793,
#   'tempo': 150.017,
#   'type': 'audio_features',
#   'id': '7lgvGRC1gN0JGgY9VGXsQT',
#   'uri': 'spotify:track:7lgvGRC1gN0JGgY9VGXsQT',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lgvGRC1gN0JGgY9VGXsQT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lgvGRC1gN0JGgY9VGXsQT',
#   'duration_ms': 209142,
#   'time_signature': 4},
#  {'danceability': 0.495,
#   'energy': 0.856,
#   'key': 0,
#   'loudness': -5.123,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.000219,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.609,
#   'tempo': 158.024,
#   'type': 'audio_features',
#   'id': '6IbnUaczZBT34DhaD6S18F',
#   'uri': 'spotify:track:6IbnUaczZBT34DhaD6S18F',
#   'track_href': 'https://api.spotify.com/v1/tracks/6IbnUaczZBT34DhaD6S18F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6IbnUaczZBT34DhaD6S18F',
#   'duration_ms': 154667,
#   'time_signature': 4},
#  {'danceability': 0.964,
#   'energy': 0.398,
#   'key': 11,
#   'loudness': -8.981,
#   'mode': 0,
#   'speechiness': 0.0795,
#   'acousticness': 0.00151,
#   'instrumentalness': 3.95e-05,
#   'liveness': 0.101,
#   'valence': 0.563,
#   'tempo': 105.012,
#   'type': 'audio_features',
#   'id': '11ZulcYY4lowvcQm4oe3VJ',
#   'uri': 'spotify:track:11ZulcYY4lowvcQm4oe3VJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/11ZulcYY4lowvcQm4oe3VJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11ZulcYY4lowvcQm4oe3VJ',
#   'duration_ms': 178405,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.777,
#   'key': 6,
#   'loudness': -4.81,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.0261,
#   'instrumentalness': 0.000358,
#   'liveness': 0.121,
#   'valence': 0.787,
#   'tempo': 132.722,
#   'type': 'audio_features',
#   'id': '4wH4dJgrsxONID6KS2tDQM',
#   'uri': 'spotify:track:4wH4dJgrsxONID6KS2tDQM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wH4dJgrsxONID6KS2tDQM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wH4dJgrsxONID6KS2tDQM',
#   'duration_ms': 258893,
#   'time_signature': 4},
#  {'danceability': 0.918,
#   'energy': 0.434,
#   'key': 9,
#   'loudness': -9.541,
#   'mode': 1,
#   'speechiness': 0.173,
#   'acousticness': 0.569,
#   'instrumentalness': 3.14e-06,
#   'liveness': 0.123,
#   'valence': 0.75,
#   'tempo': 109.997,
#   'type': 'audio_features',
#   'id': '6NWdgyVsjp2bJ11PToXCr1',
#   'uri': 'spotify:track:6NWdgyVsjp2bJ11PToXCr1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NWdgyVsjp2bJ11PToXCr1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NWdgyVsjp2bJ11PToXCr1',
#   'duration_ms': 188735,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.907,
#   'key': 6,
#   'loudness': -5.154,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.167,
#   'instrumentalness': 0.00108,
#   'liveness': 0.245,
#   'valence': 0.975,
#   'tempo': 127.153,
#   'type': 'audio_features',
#   'id': '1zVMJGPMWKmD4cjTTyf68y',
#   'uri': 'spotify:track:1zVMJGPMWKmD4cjTTyf68y',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zVMJGPMWKmD4cjTTyf68y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zVMJGPMWKmD4cjTTyf68y',
#   'duration_ms': 272227,
#   'time_signature': 4},
#  {'danceability': 0.802,
#   'energy': 0.488,
#   'key': 1,
#   'loudness': -9.304,
#   'mode': 1,
#   'speechiness': 0.0813,
#   'acousticness': 0.572,
#   'instrumentalness': 0.0598,
#   'liveness': 0.0763,
#   'valence': 0.624,
#   'tempo': 95.77,
#   'type': 'audio_features',
#   'id': '1ko2lVN0vKGUl9zrU0qSlT',
#   'uri': 'spotify:track:1ko2lVN0vKGUl9zrU0qSlT',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ko2lVN0vKGUl9zrU0qSlT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ko2lVN0vKGUl9zrU0qSlT',
#   'duration_ms': 237106,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.676,
#   'key': 2,
#   'loudness': -3.442,
#   'mode': 1,
#   'speechiness': 0.0263,
#   'acousticness': 0.0807,
#   'instrumentalness': 0,
#   'liveness': 0.0831,
#   'valence': 0.273,
#   'tempo': 113.98,
#   'type': 'audio_features',
#   'id': '2tznHmp70DxMyr2XhWLOW0',
#   'uri': 'spotify:track:2tznHmp70DxMyr2XhWLOW0',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tznHmp70DxMyr2XhWLOW0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tznHmp70DxMyr2XhWLOW0',
#   'duration_ms': 208760,
#   'time_signature': 4},
#  {'danceability': 0.763,
#   'energy': 0.53,
#   'key': 5,
#   'loudness': -5.554,
#   'mode': 0,
#   'speechiness': 0.0577,
#   'acousticness': 0.272,
#   'instrumentalness': 0,
#   'liveness': 0.16,
#   'valence': 0.469,
#   'tempo': 97.033,
#   'type': 'audio_features',
#   'id': '1uH1Nd8vet2uoZSDFSDwbh',
#   'uri': 'spotify:track:1uH1Nd8vet2uoZSDFSDwbh',
#   'track_href': 'https://api.spotify.com/v1/tracks/1uH1Nd8vet2uoZSDFSDwbh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uH1Nd8vet2uoZSDFSDwbh',
#   'duration_ms': 231893,
#   'time_signature': 4},
#  {'danceability': 0.72,
#   'energy': 0.197,
#   'key': 2,
#   'loudness': -12.494,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.981,
#   'instrumentalness': 0.00187,
#   'liveness': 0.1,
#   'valence': 0.284,
#   'tempo': 120.024,
#   'type': 'audio_features',
#   'id': '18V1UiYRvWYwn01CRDbbuR',
#   'uri': 'spotify:track:18V1UiYRvWYwn01CRDbbuR',
#   'track_href': 'https://api.spotify.com/v1/tracks/18V1UiYRvWYwn01CRDbbuR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18V1UiYRvWYwn01CRDbbuR',
#   'duration_ms': 197360,
#   'time_signature': 4},
#  {'danceability': 0.474,
#   'energy': 0.921,
#   'key': 9,
#   'loudness': -10.431,
#   'mode': 0,
#   'speechiness': 0.0457,
#   'acousticness': 0.00491,
#   'instrumentalness': 0.859,
#   'liveness': 0.476,
#   'valence': 0.696,
#   'tempo': 93.007,
#   'type': 'audio_features',
#   'id': '5s2zbxZI4Ym5LTKwjZHS2V',
#   'uri': 'spotify:track:5s2zbxZI4Ym5LTKwjZHS2V',
#   'track_href': 'https://api.spotify.com/v1/tracks/5s2zbxZI4Ym5LTKwjZHS2V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5s2zbxZI4Ym5LTKwjZHS2V',
#   'duration_ms': 122339,
#   'time_signature': 4},
#  {'danceability': 0.612,
#   'energy': 0.807,
#   'key': 10,
#   'loudness': -2.81,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0495,
#   'instrumentalness': 0.0177,
#   'liveness': 0.101,
#   'valence': 0.398,
#   'tempo': 124.053,
#   'type': 'audio_features',
#   'id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'uri': 'spotify:track:2QjOHCTQ1Jl3zawyYOpxh6',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QjOHCTQ1Jl3zawyYOpxh6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QjOHCTQ1Jl3zawyYOpxh6',
#   'duration_ms': 240400,
#   'time_signature': 4},
#  {'danceability': 0.879,
#   'energy': 0.574,
#   'key': 10,
#   'loudness': -5.602,
#   'mode': 0,
#   'speechiness': 0.391,
#   'acousticness': 0.519,
#   'instrumentalness': 8.76e-06,
#   'liveness': 0.144,
#   'valence': 0.346,
#   'tempo': 144.911,
#   'type': 'audio_features',
#   'id': '2HYvkdq6lpFXkVz9Tfqi8r',
#   'uri': 'spotify:track:2HYvkdq6lpFXkVz9Tfqi8r',
#   'track_href': 'https://api.spotify.com/v1/tracks/2HYvkdq6lpFXkVz9Tfqi8r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HYvkdq6lpFXkVz9Tfqi8r',
#   'duration_ms': 243463,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.526,
#   'key': 7,
#   'loudness': -6.478,
#   'mode': 1,
#   'speechiness': 0.261,
#   'acousticness': 0.0802,
#   'instrumentalness': 0,
#   'liveness': 0.066,
#   'valence': 0.902,
#   'tempo': 75.002,
#   'type': 'audio_features',
#   'id': '4pBhTGnL5N5KqsyqU58jee',
#   'uri': 'spotify:track:4pBhTGnL5N5KqsyqU58jee',
#   'track_href': 'https://api.spotify.com/v1/tracks/4pBhTGnL5N5KqsyqU58jee',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4pBhTGnL5N5KqsyqU58jee',
#   'duration_ms': 118400,
#   'time_signature': 4},
#  {'danceability': 0.833,
#   'energy': 0.748,
#   'key': 1,
#   'loudness': -5.963,
#   'mode': 1,
#   'speechiness': 0.229,
#   'acousticness': 0.0331,
#   'instrumentalness': 1.44e-06,
#   'liveness': 0.0728,
#   'valence': 0.484,
#   'tempo': 119.925,
#   'type': 'audio_features',
#   'id': '4KrhaZm4JRkNO4HRdLvJIG',
#   'uri': 'spotify:track:4KrhaZm4JRkNO4HRdLvJIG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KrhaZm4JRkNO4HRdLvJIG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KrhaZm4JRkNO4HRdLvJIG',
#   'duration_ms': 140000,
#   'time_signature': 4},
#  {'danceability': 0.714,
#   'energy': 0.594,
#   'key': 0,
#   'loudness': -10.63,
#   'mode': 1,
#   'speechiness': 0.43,
#   'acousticness': 0.965,
#   'instrumentalness': 0.255,
#   'liveness': 0.129,
#   'valence': 0.45,
#   'tempo': 169.837,
#   'type': 'audio_features',
#   'id': '4jY3GWEqlrTALvVE1j7VHI',
#   'uri': 'spotify:track:4jY3GWEqlrTALvVE1j7VHI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4jY3GWEqlrTALvVE1j7VHI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jY3GWEqlrTALvVE1j7VHI',
#   'duration_ms': 158436,
#   'time_signature': 4},
#  {'danceability': 0.749,
#   'energy': 0.463,
#   'key': 11,
#   'loudness': -8.433,
#   'mode': 1,
#   'speechiness': 0.0828,
#   'acousticness': 0.208,
#   'instrumentalness': 0.0371,
#   'liveness': 0.337,
#   'valence': 0.19,
#   'tempo': 90.028,
#   'type': 'audio_features',
#   'id': '60ynsPSSKe6O3sfwRnIBRf',
#   'uri': 'spotify:track:60ynsPSSKe6O3sfwRnIBRf',
#   'track_href': 'https://api.spotify.com/v1/tracks/60ynsPSSKe6O3sfwRnIBRf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60ynsPSSKe6O3sfwRnIBRf',
#   'duration_ms': 226987,
#   'time_signature': 4},
#  {'danceability': 0.979,
#   'energy': 0.41,
#   'key': 8,
#   'loudness': -11.056,
#   'mode': 0,
#   'speechiness': 0.112,
#   'acousticness': 0.658,
#   'instrumentalness': 3.42e-05,
#   'liveness': 0.205,
#   'valence': 0.74,
#   'tempo': 119.971,
#   'type': 'audio_features',
#   'id': '7CCCX50zGHMTuHsyKQy03l',
#   'uri': 'spotify:track:7CCCX50zGHMTuHsyKQy03l',
#   'track_href': 'https://api.spotify.com/v1/tracks/7CCCX50zGHMTuHsyKQy03l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7CCCX50zGHMTuHsyKQy03l',
#   'duration_ms': 180122,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.631,
#   'key': 2,
#   'loudness': -6.478,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.0483,
#   'instrumentalness': 1.13e-05,
#   'liveness': 0.104,
#   'valence': 0.8,
#   'tempo': 92.004,
#   'type': 'audio_features',
#   'id': '48q0vSHcJdhK3IiXH8C5WJ',
#   'uri': 'spotify:track:48q0vSHcJdhK3IiXH8C5WJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/48q0vSHcJdhK3IiXH8C5WJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48q0vSHcJdhK3IiXH8C5WJ',
#   'duration_ms': 161124,
#   'time_signature': 4},
#  {'danceability': 0.881,
#   'energy': 0.623,
#   'key': 1,
#   'loudness': -9.662,
#   'mode': 1,
#   'speechiness': 0.119,
#   'acousticness': 0.257,
#   'instrumentalness': 1.5e-06,
#   'liveness': 0.0964,
#   'valence': 0.745,
#   'tempo': 88.953,
#   'type': 'audio_features',
#   'id': '3EikYy40GMSp8l5mDV6IQo',
#   'uri': 'spotify:track:3EikYy40GMSp8l5mDV6IQo',
#   'track_href': 'https://api.spotify.com/v1/tracks/3EikYy40GMSp8l5mDV6IQo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EikYy40GMSp8l5mDV6IQo',
#   'duration_ms': 129547,
#   'time_signature': 4},
#  {'danceability': 0.685,
#   'energy': 0.61,
#   'key': 0,
#   'loudness': -5.221,
#   'mode': 0,
#   'speechiness': 0.0439,
#   'acousticness': 0.323,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.323,
#   'tempo': 94.384,
#   'type': 'audio_features',
#   'id': '4mCf3vQf7z0Yseo0RxAi3V',
#   'uri': 'spotify:track:4mCf3vQf7z0Yseo0RxAi3V',
#   'track_href': 'https://api.spotify.com/v1/tracks/4mCf3vQf7z0Yseo0RxAi3V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4mCf3vQf7z0Yseo0RxAi3V',
#   'duration_ms': 186467,
#   'time_signature': 3},
#  {'danceability': 0.967,
#   'energy': 0.583,
#   'key': 7,
#   'loudness': -5.562,
#   'mode': 0,
#   'speechiness': 0.0789,
#   'acousticness': 0.0584,
#   'instrumentalness': 0,
#   'liveness': 0.0519,
#   'valence': 0.964,
#   'tempo': 117.0,
#   'type': 'audio_features',
#   'id': '0O45fw2L5vsWpdsOdXwNAR',
#   'uri': 'spotify:track:0O45fw2L5vsWpdsOdXwNAR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0O45fw2L5vsWpdsOdXwNAR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0O45fw2L5vsWpdsOdXwNAR',
#   'duration_ms': 242733,
#   'time_signature': 4},
#  {'danceability': 0.886,
#   'energy': 0.743,
#   'key': 6,
#   'loudness': -6.797,
#   'mode': 0,
#   'speechiness': 0.0812,
#   'acousticness': 0.0358,
#   'instrumentalness': 0.000198,
#   'liveness': 0.0511,
#   'valence': 0.941,
#   'tempo': 131.902,
#   'type': 'audio_features',
#   'id': '7L6G0wpIUiPXuvoo7qhb06',
#   'uri': 'spotify:track:7L6G0wpIUiPXuvoo7qhb06',
#   'track_href': 'https://api.spotify.com/v1/tracks/7L6G0wpIUiPXuvoo7qhb06',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7L6G0wpIUiPXuvoo7qhb06',
#   'duration_ms': 139760,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.97,
#   'key': 10,
#   'loudness': -6.098,
#   'mode': 0,
#   'speechiness': 0.0506,
#   'acousticness': 0.0569,
#   'instrumentalness': 6.13e-05,
#   'liveness': 0.154,
#   'valence': 0.868,
#   'tempo': 114.328,
#   'type': 'audio_features',
#   'id': '2gam98EZKrF9XuOkU13ApN',
#   'uri': 'spotify:track:2gam98EZKrF9XuOkU13ApN',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gam98EZKrF9XuOkU13ApN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gam98EZKrF9XuOkU13ApN',
#   'duration_ms': 242293,
#   'time_signature': 4},
#  {'danceability': 0.957,
#   'energy': 0.437,
#   'key': 11,
#   'loudness': -7.882,
#   'mode': 1,
#   'speechiness': 0.359,
#   'acousticness': 0.00402,
#   'instrumentalness': 0,
#   'liveness': 0.219,
#   'valence': 0.616,
#   'tempo': 130.058,
#   'type': 'audio_features',
#   'id': '4aarlAfLKVCTxUDNgbwhjH',
#   'uri': 'spotify:track:4aarlAfLKVCTxUDNgbwhjH',
#   'track_href': 'https://api.spotify.com/v1/tracks/4aarlAfLKVCTxUDNgbwhjH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4aarlAfLKVCTxUDNgbwhjH',
#   'duration_ms': 137984,
#   'time_signature': 4},
#  {'danceability': 0.641,
#   'energy': 0.598,
#   'key': 7,
#   'loudness': -5.7,
#   'mode': 0,
#   'speechiness': 0.324,
#   'acousticness': 0.381,
#   'instrumentalness': 0,
#   'liveness': 0.0921,
#   'valence': 0.285,
#   'tempo': 131.459,
#   'type': 'audio_features',
#   'id': '5hChuUMe5iHfjkXgzj1D4b',
#   'uri': 'spotify:track:5hChuUMe5iHfjkXgzj1D4b',
#   'track_href': 'https://api.spotify.com/v1/tracks/5hChuUMe5iHfjkXgzj1D4b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hChuUMe5iHfjkXgzj1D4b',
#   'duration_ms': 199706,
#   'time_signature': 5},
#  {'danceability': 0.722,
#   'energy': 0.893,
#   'key': 0,
#   'loudness': -3.255,
#   'mode': 0,
#   'speechiness': 0.0475,
#   'acousticness': 0.0441,
#   'instrumentalness': 0.000937,
#   'liveness': 0.0673,
#   'valence': 0.439,
#   'tempo': 119.932,
#   'type': 'audio_features',
#   'id': '3iw6V4LH7yPj1ESORX9RIN',
#   'uri': 'spotify:track:3iw6V4LH7yPj1ESORX9RIN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3iw6V4LH7yPj1ESORX9RIN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iw6V4LH7yPj1ESORX9RIN',
#   'duration_ms': 116750,
#   'time_signature': 4},
#  {'danceability': 0.766,
#   'energy': 0.64,
#   'key': 0,
#   'loudness': -8.899,
#   'mode': 1,
#   'speechiness': 0.0345,
#   'acousticness': 0.051,
#   'instrumentalness': 0,
#   'liveness': 0.237,
#   'valence': 0.67,
#   'tempo': 100.044,
#   'type': 'audio_features',
#   'id': '0qgZvYWLIqDn0tXimF8gPa',
#   'uri': 'spotify:track:0qgZvYWLIqDn0tXimF8gPa',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qgZvYWLIqDn0tXimF8gPa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qgZvYWLIqDn0tXimF8gPa',
#   'duration_ms': 165600,
#   'time_signature': 4},
#  {'danceability': 0.893,
#   'energy': 0.565,
#   'key': 1,
#   'loudness': -4.74,
#   'mode': 1,
#   'speechiness': 0.268,
#   'acousticness': 0.0754,
#   'instrumentalness': 0,
#   'liveness': 0.0375,
#   'valence': 0.808,
#   'tempo': 81.009,
#   'type': 'audio_features',
#   'id': '1xMvdOFQaql3EBkHmuh2TK',
#   'uri': 'spotify:track:1xMvdOFQaql3EBkHmuh2TK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xMvdOFQaql3EBkHmuh2TK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xMvdOFQaql3EBkHmuh2TK',
#   'duration_ms': 156432,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.922,
#   'key': 9,
#   'loudness': -2.666,
#   'mode': 0,
#   'speechiness': 0.0728,
#   'acousticness': 0.00475,
#   'instrumentalness': 0.000162,
#   'liveness': 0.422,
#   'valence': 0.49,
#   'tempo': 95.975,
#   'type': 'audio_features',
#   'id': '2kS6td1yvmpNgZTt1q5pQq',
#   'uri': 'spotify:track:2kS6td1yvmpNgZTt1q5pQq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kS6td1yvmpNgZTt1q5pQq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kS6td1yvmpNgZTt1q5pQq',
#   'duration_ms': 181680,
#   'time_signature': 4}]

# %%
audio_features_df = pd.DataFrame(track_features_api_response['audio_features'])

# %%
audio_features_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.471   0.229    8    -6.504     1       0.0358      0.953000
# 1          0.699   0.882    4    -3.896     0       0.0311      0.002960
# 2          0.610   0.508    8    -6.682     0       0.1520      0.297000
# 3          0.720   0.744    1    -6.938     0       0.1200      0.237000
# 4          0.523   0.606    1    -4.754     0       0.0301      0.512000
# 5          0.778   0.695    4    -6.865     0       0.0913      0.174000
# 6          0.601   0.703    7    -6.240     1       0.0379      0.175000
# 7          0.677   0.696    0    -6.181     1       0.1190      0.321000
# 8          0.627   0.935    4    -3.257     1       0.0495      0.001450
# 9          0.949   0.790    8    -5.957     1       0.0756      0.004370
# 10         0.719   0.847    0    -6.340     0       0.0916      0.002010
# 11         0.938   0.463    1   -13.124     1       0.4790      0.035000
# 12         0.504   0.711    9    -5.864     1       0.0452      0.058500
# 13         0.421   0.277   11   -10.340     1       0.0368      0.637000
# 14         0.868   0.795   11    -6.044     1       0.2690      0.001200
# 15         0.653   0.524   11    -9.016     0       0.0502      0.112000
# 16         0.745   0.740    0    -6.558     1       0.0970      0.530000
# 17         0.880   0.443   11    -6.359     0       0.0653      0.462000
# 18         0.597   0.617    8    -7.482     0       0.2820      0.463000
# 19         0.799   0.543   10    -6.094     0       0.2400      0.051200
# 20         0.739   0.754    8    -5.034     1       0.0350      0.043100
# 21         0.495   0.856    0    -5.123     0       0.0311      0.000219
# 22         0.964   0.398   11    -8.981     0       0.0795      0.001510
# 23         0.796   0.777    6    -4.810     1       0.0397      0.026100
# 24         0.918   0.434    9    -9.541     1       0.1730      0.569000
# 25         0.719   0.907    6    -5.154     0       0.0502      0.167000
# 26         0.802   0.488    1    -9.304     1       0.0813      0.572000
# 27         0.636   0.676    2    -3.442     1       0.0263      0.080700
# 28         0.763   0.530    5    -5.554     0       0.0577      0.272000
# 29         0.720   0.197    2   -12.494     1       0.0361      0.981000
# 30         0.474   0.921    9   -10.431     0       0.0457      0.004910
# 31         0.612   0.807   10    -2.810     1       0.0336      0.049500
# 32         0.879   0.574   10    -5.602     0       0.3910      0.519000
# 33         0.783   0.526    7    -6.478     1       0.2610      0.080200
# 34         0.833   0.748    1    -5.963     1       0.2290      0.033100
# 35         0.714   0.594    0   -10.630     1       0.4300      0.965000
# 36         0.749   0.463   11    -8.433     1       0.0828      0.208000
# 37         0.979   0.410    8   -11.056     0       0.1120      0.658000
# 38         0.691   0.631    2    -6.478     1       0.0368      0.048300
# 39         0.881   0.623    1    -9.662     1       0.1190      0.257000
# 40         0.685   0.610    0    -5.221     0       0.0439      0.323000
# 41         0.967   0.583    7    -5.562     0       0.0789      0.058400
# 42         0.886   0.743    6    -6.797     0       0.0812      0.035800
# 43         0.808   0.970   10    -6.098     0       0.0506      0.056900
# 44         0.957   0.437   11    -7.882     1       0.3590      0.004020
# 45         0.641   0.598    7    -5.700     0       0.3240      0.381000
# 46         0.722   0.893    0    -3.255     0       0.0475      0.044100
# 47         0.766   0.640    0    -8.899     1       0.0345      0.051000
# 48         0.893   0.565    1    -4.740     1       0.2680      0.075400
# 49         0.527   0.922    9    -2.666     0       0.0728      0.004750
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0909    0.358   68.410  audio_features
# 1           0.054400    0.1300    0.657  120.016  audio_features
# 2           0.000000    0.3840    0.758  178.818  audio_features
# 3           0.000000    0.2550    0.619   78.953  audio_features
# 4           0.000000    0.1060    0.065  145.837  audio_features
# 5           0.000000    0.1510    0.472  149.996  audio_features
# 6           0.000084    0.5710    0.673  106.164  audio_features
# 7           0.000000    0.4200    0.464   90.030  audio_features
# 8           0.000017    0.3350    0.903   80.986  audio_features
# 9           0.000000    0.0816    0.807  117.002  audio_features
# 10          0.020400    0.2210    0.444  127.963  audio_features
# 11          0.006520    0.1000    0.460  119.878  audio_features
# 12          0.000018    0.3820    0.500  134.824  audio_features
# 13          0.000072    0.1030    0.130  115.153  audio_features
# 14          0.019300    0.0461    0.819  166.000  audio_features
# 15          0.000000    0.2030    0.553   83.970  audio_features
# 16          0.000074    0.0936    0.360   97.735  audio_features
# 17          0.000007    0.1220    0.803  138.018  audio_features
# 18          0.000000    0.6600    0.889   97.923  audio_features
# 19          0.042500    0.1340    0.250  187.906  audio_features
# 20          0.000000    0.0999    0.793  150.017  audio_features
# 21          0.000000    0.1030    0.609  158.024  audio_features
# 22          0.000039    0.1010    0.563  105.012  audio_features
# 23          0.000358    0.1210    0.787  132.722  audio_features
# 24          0.000003    0.1230    0.750  109.997  audio_features
# 25          0.001080    0.2450    0.975  127.153  audio_features
# 26          0.059800    0.0763    0.624   95.770  audio_features
# 27          0.000000    0.0831    0.273  113.980  audio_features
# 28          0.000000    0.1600    0.469   97.033  audio_features
# 29          0.001870    0.1000    0.284  120.024  audio_features
# 30          0.859000    0.4760    0.696   93.007  audio_features
# 31          0.017700    0.1010    0.398  124.053  audio_features
# 32          0.000009    0.1440    0.346  144.911  audio_features
# 33          0.000000    0.0660    0.902   75.002  audio_features
# 34          0.000001    0.0728    0.484  119.925  audio_features
# 35          0.255000    0.1290    0.450  169.837  audio_features
# 36          0.037100    0.3370    0.190   90.028  audio_features
# 37          0.000034    0.2050    0.740  119.971  audio_features
# 38          0.000011    0.1040    0.800   92.004  audio_features
# 39          0.000002    0.0964    0.745   88.953  audio_features
# 40          0.000000    0.1020    0.323   94.384  audio_features
# 41          0.000000    0.0519    0.964  117.000  audio_features
# 42          0.000198    0.0511    0.941  131.902  audio_features
# 43          0.000061    0.1540    0.868  114.328  audio_features
# 44          0.000000    0.2190    0.616  130.058  audio_features
# 45          0.000000    0.0921    0.285  131.459  audio_features
# 46          0.000937    0.0673    0.439  119.932  audio_features
# 47          0.000000    0.2370    0.670  100.044  audio_features
# 48          0.000000    0.0375    0.808   81.009  audio_features
# 49          0.000162    0.4220    0.490   95.975  audio_features
#
#                         id                                   uri  \
# 0   0PKAijroHpnEtdY20bkGdr  spotify:track:0PKAijroHpnEtdY20bkGdr
# 1   6jg5SRvdGxvJ0DzNV0UqEK  spotify:track:6jg5SRvdGxvJ0DzNV0UqEK
# 2   3BZEcbdtXQSo7OrvKRJ6mb  spotify:track:3BZEcbdtXQSo7OrvKRJ6mb
# 3   2Lhdl74nwwVGOE2Gv35QuK  spotify:track:2Lhdl74nwwVGOE2Gv35QuK
# 4   161DnLWsx1i3u1JT05lzqU  spotify:track:161DnLWsx1i3u1JT05lzqU
# 5   0jdso14vaFnpRazMLEZovF  spotify:track:0jdso14vaFnpRazMLEZovF
# 6   2cX2coZS1PYBfPs8wgbdWE  spotify:track:2cX2coZS1PYBfPs8wgbdWE
# 7   4iJyoBOLtHqaGxP12qzhQI  spotify:track:4iJyoBOLtHqaGxP12qzhQI
# 8   589Lt4lVKxd1qXOrPaAHkB  spotify:track:589Lt4lVKxd1qXOrPaAHkB
# 9   4NOZ35Dhucr6UlVyLOtktd  spotify:track:4NOZ35Dhucr6UlVyLOtktd
# 10  5WQQIDU3HRaMyPkob8mpFb  spotify:track:5WQQIDU3HRaMyPkob8mpFb
# 11  2BKyXCkxhZRGwREqZacJ9M  spotify:track:2BKyXCkxhZRGwREqZacJ9M
# 12  3qGHAKgjQruzj6doKkyEb5  spotify:track:3qGHAKgjQruzj6doKkyEb5
# 13  0TCmhnbMpw5zwPsTvlXTJi  spotify:track:0TCmhnbMpw5zwPsTvlXTJi
# 14  1M4OcYkxAtu3ErzSgDEfoi  spotify:track:1M4OcYkxAtu3ErzSgDEfoi
# 15  6tDDoYIxWvMLTdKpjFkc1B  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
# 16  3FxPbp05KjMBa4HbhAJTH0  spotify:track:3FxPbp05KjMBa4HbhAJTH0
# 17  60PAzFNW3vAiAiVK6DRJfB  spotify:track:60PAzFNW3vAiAiVK6DRJfB
# 18  1j3SdMJfeRJXycCp50boYE  spotify:track:1j3SdMJfeRJXycCp50boYE
# 19  1yLTcitjbEJr7a4jyDB0Lz  spotify:track:1yLTcitjbEJr7a4jyDB0Lz
# 20  7lgvGRC1gN0JGgY9VGXsQT  spotify:track:7lgvGRC1gN0JGgY9VGXsQT
# 21  6IbnUaczZBT34DhaD6S18F  spotify:track:6IbnUaczZBT34DhaD6S18F
# 22  11ZulcYY4lowvcQm4oe3VJ  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 23  4wH4dJgrsxONID6KS2tDQM  spotify:track:4wH4dJgrsxONID6KS2tDQM
# 24  6NWdgyVsjp2bJ11PToXCr1  spotify:track:6NWdgyVsjp2bJ11PToXCr1
# 25  1zVMJGPMWKmD4cjTTyf68y  spotify:track:1zVMJGPMWKmD4cjTTyf68y
# 26  1ko2lVN0vKGUl9zrU0qSlT  spotify:track:1ko2lVN0vKGUl9zrU0qSlT
# 27  2tznHmp70DxMyr2XhWLOW0  spotify:track:2tznHmp70DxMyr2XhWLOW0
# 28  1uH1Nd8vet2uoZSDFSDwbh  spotify:track:1uH1Nd8vet2uoZSDFSDwbh
# 29  18V1UiYRvWYwn01CRDbbuR  spotify:track:18V1UiYRvWYwn01CRDbbuR
# 30  5s2zbxZI4Ym5LTKwjZHS2V  spotify:track:5s2zbxZI4Ym5LTKwjZHS2V
# 31  2QjOHCTQ1Jl3zawyYOpxh6  spotify:track:2QjOHCTQ1Jl3zawyYOpxh6
# 32  2HYvkdq6lpFXkVz9Tfqi8r  spotify:track:2HYvkdq6lpFXkVz9Tfqi8r
# 33  4pBhTGnL5N5KqsyqU58jee  spotify:track:4pBhTGnL5N5KqsyqU58jee
# 34  4KrhaZm4JRkNO4HRdLvJIG  spotify:track:4KrhaZm4JRkNO4HRdLvJIG
# 35  4jY3GWEqlrTALvVE1j7VHI  spotify:track:4jY3GWEqlrTALvVE1j7VHI
# 36  60ynsPSSKe6O3sfwRnIBRf  spotify:track:60ynsPSSKe6O3sfwRnIBRf
# 37  7CCCX50zGHMTuHsyKQy03l  spotify:track:7CCCX50zGHMTuHsyKQy03l
# 38  48q0vSHcJdhK3IiXH8C5WJ  spotify:track:48q0vSHcJdhK3IiXH8C5WJ
# 39  3EikYy40GMSp8l5mDV6IQo  spotify:track:3EikYy40GMSp8l5mDV6IQo
# 40  4mCf3vQf7z0Yseo0RxAi3V  spotify:track:4mCf3vQf7z0Yseo0RxAi3V
# 41  0O45fw2L5vsWpdsOdXwNAR  spotify:track:0O45fw2L5vsWpdsOdXwNAR
# 42  7L6G0wpIUiPXuvoo7qhb06  spotify:track:7L6G0wpIUiPXuvoo7qhb06
# 43  2gam98EZKrF9XuOkU13ApN  spotify:track:2gam98EZKrF9XuOkU13ApN
# 44  4aarlAfLKVCTxUDNgbwhjH  spotify:track:4aarlAfLKVCTxUDNgbwhjH
# 45  5hChuUMe5iHfjkXgzj1D4b  spotify:track:5hChuUMe5iHfjkXgzj1D4b
# 46  3iw6V4LH7yPj1ESORX9RIN  spotify:track:3iw6V4LH7yPj1ESORX9RIN
# 47  0qgZvYWLIqDn0tXimF8gPa  spotify:track:0qgZvYWLIqDn0tXimF8gPa
# 48  1xMvdOFQaql3EBkHmuh2TK  spotify:track:1xMvdOFQaql3EBkHmuh2TK
# 49  2kS6td1yvmpNgZTt1q5pQq  spotify:track:2kS6td1yvmpNgZTt1q5pQq
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/0PKAijroHpnE...
# 1   https://api.spotify.com/v1/tracks/6jg5SRvdGxvJ...
# 2   https://api.spotify.com/v1/tracks/3BZEcbdtXQSo...
# 3   https://api.spotify.com/v1/tracks/2Lhdl74nwwVG...
# 4   https://api.spotify.com/v1/tracks/161DnLWsx1i3...
# 5   https://api.spotify.com/v1/tracks/0jdso14vaFnp...
# 6   https://api.spotify.com/v1/tracks/2cX2coZS1PYB...
# 7   https://api.spotify.com/v1/tracks/4iJyoBOLtHqa...
# 8   https://api.spotify.com/v1/tracks/589Lt4lVKxd1...
# 9   https://api.spotify.com/v1/tracks/4NOZ35Dhucr6...
# 10  https://api.spotify.com/v1/tracks/5WQQIDU3HRaM...
# 11  https://api.spotify.com/v1/tracks/2BKyXCkxhZRG...
# 12  https://api.spotify.com/v1/tracks/3qGHAKgjQruz...
# 13  https://api.spotify.com/v1/tracks/0TCmhnbMpw5z...
# 14  https://api.spotify.com/v1/tracks/1M4OcYkxAtu3...
# 15  https://api.spotify.com/v1/tracks/6tDDoYIxWvML...
# 16  https://api.spotify.com/v1/tracks/3FxPbp05KjMB...
# 17  https://api.spotify.com/v1/tracks/60PAzFNW3vAi...
# 18  https://api.spotify.com/v1/tracks/1j3SdMJfeRJX...
# 19  https://api.spotify.com/v1/tracks/1yLTcitjbEJr...
# 20  https://api.spotify.com/v1/tracks/7lgvGRC1gN0J...
# 21  https://api.spotify.com/v1/tracks/6IbnUaczZBT3...
# 22  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 23  https://api.spotify.com/v1/tracks/4wH4dJgrsxON...
# 24  https://api.spotify.com/v1/tracks/6NWdgyVsjp2b...
# 25  https://api.spotify.com/v1/tracks/1zVMJGPMWKmD...
# 26  https://api.spotify.com/v1/tracks/1ko2lVN0vKGU...
# 27  https://api.spotify.com/v1/tracks/2tznHmp70DxM...
# 28  https://api.spotify.com/v1/tracks/1uH1Nd8vet2u...
# 29  https://api.spotify.com/v1/tracks/18V1UiYRvWYw...
# 30  https://api.spotify.com/v1/tracks/5s2zbxZI4Ym5...
# 31  https://api.spotify.com/v1/tracks/2QjOHCTQ1Jl3...
# 32  https://api.spotify.com/v1/tracks/2HYvkdq6lpFX...
# 33  https://api.spotify.com/v1/tracks/4pBhTGnL5N5K...
# 34  https://api.spotify.com/v1/tracks/4KrhaZm4JRkN...
# 35  https://api.spotify.com/v1/tracks/4jY3GWEqlrTA...
# 36  https://api.spotify.com/v1/tracks/60ynsPSSKe6O...
# 37  https://api.spotify.com/v1/tracks/7CCCX50zGHMT...
# 38  https://api.spotify.com/v1/tracks/48q0vSHcJdhK...
# 39  https://api.spotify.com/v1/tracks/3EikYy40GMSp...
# 40  https://api.spotify.com/v1/tracks/4mCf3vQf7z0Y...
# 41  https://api.spotify.com/v1/tracks/0O45fw2L5vsW...
# 42  https://api.spotify.com/v1/tracks/7L6G0wpIUiPX...
# 43  https://api.spotify.com/v1/tracks/2gam98EZKrF9...
# 44  https://api.spotify.com/v1/tracks/4aarlAfLKVCT...
# 45  https://api.spotify.com/v1/tracks/5hChuUMe5iHf...
# 46  https://api.spotify.com/v1/tracks/3iw6V4LH7yPj...
# 47  https://api.spotify.com/v1/tracks/0qgZvYWLIqDn...
# 48  https://api.spotify.com/v1/tracks/1xMvdOFQaql3...
# 49  https://api.spotify.com/v1/tracks/2kS6td1yvmpN...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/0PKA...       137250
# 1   https://api.spotify.com/v1/audio-analysis/6jg5...       196813
# 2   https://api.spotify.com/v1/audio-analysis/3BZE...       137876
# 3   https://api.spotify.com/v1/audio-analysis/2Lhd...       243773
# 4   https://api.spotify.com/v1/audio-analysis/161D...       217867
# 5   https://api.spotify.com/v1/audio-analysis/0jds...       132780
# 6   https://api.spotify.com/v1/audio-analysis/2cX2...       196213
# 7   https://api.spotify.com/v1/audio-analysis/4iJy...       198082
# 8   https://api.spotify.com/v1/audio-analysis/589L...       137601
# 9   https://api.spotify.com/v1/audio-analysis/4NOZ...       246053
# 10  https://api.spotify.com/v1/audio-analysis/5WQQ...       242680
# 11  https://api.spotify.com/v1/audio-analysis/2BKy...       111621
# 12  https://api.spotify.com/v1/audio-analysis/3qGH...       232933
# 13  https://api.spotify.com/v1/audio-analysis/0TCm...       248827
# 14  https://api.spotify.com/v1/audio-analysis/1M4O...       156945
# 15  https://api.spotify.com/v1/audio-analysis/6tDD...       160191
# 16  https://api.spotify.com/v1/audio-analysis/3FxP...        80118
# 17  https://api.spotify.com/v1/audio-analysis/60PA...       221240
# 18  https://api.spotify.com/v1/audio-analysis/1j3S...       275520
# 19  https://api.spotify.com/v1/audio-analysis/1yLT...        85742
# 20  https://api.spotify.com/v1/audio-analysis/7lgv...       209142
# 21  https://api.spotify.com/v1/audio-analysis/6Ibn...       154667
# 22  https://api.spotify.com/v1/audio-analysis/11Zu...       178405
# 23  https://api.spotify.com/v1/audio-analysis/4wH4...       258893
# 24  https://api.spotify.com/v1/audio-analysis/6NWd...       188735
# 25  https://api.spotify.com/v1/audio-analysis/1zVM...       272227
# 26  https://api.spotify.com/v1/audio-analysis/1ko2...       237106
# 27  https://api.spotify.com/v1/audio-analysis/2tzn...       208760
# 28  https://api.spotify.com/v1/audio-analysis/1uH1...       231893
# 29  https://api.spotify.com/v1/audio-analysis/18V1...       197360
# 30  https://api.spotify.com/v1/audio-analysis/5s2z...       122339
# 31  https://api.spotify.com/v1/audio-analysis/2QjO...       240400
# 32  https://api.spotify.com/v1/audio-analysis/2HYv...       243463
# 33  https://api.spotify.com/v1/audio-analysis/4pBh...       118400
# 34  https://api.spotify.com/v1/audio-analysis/4Krh...       140000
# 35  https://api.spotify.com/v1/audio-analysis/4jY3...       158436
# 36  https://api.spotify.com/v1/audio-analysis/60yn...       226987
# 37  https://api.spotify.com/v1/audio-analysis/7CCC...       180122
# 38  https://api.spotify.com/v1/audio-analysis/48q0...       161124
# 39  https://api.spotify.com/v1/audio-analysis/3Eik...       129547
# 40  https://api.spotify.com/v1/audio-analysis/4mCf...       186467
# 41  https://api.spotify.com/v1/audio-analysis/0O45...       242733
# 42  https://api.spotify.com/v1/audio-analysis/7L6G...       139760
# 43  https://api.spotify.com/v1/audio-analysis/2gam...       242293
# 44  https://api.spotify.com/v1/audio-analysis/4aar...       137984
# 45  https://api.spotify.com/v1/audio-analysis/5hCh...       199706
# 46  https://api.spotify.com/v1/audio-analysis/3iw6...       116750
# 47  https://api.spotify.com/v1/audio-analysis/0qgZ...       165600
# 48  https://api.spotify.com/v1/audio-analysis/1xMv...       156432
# 49  https://api.spotify.com/v1/audio-analysis/2kS6...       181680
#
#     time_signature
# 0                3
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               3
# 41               4
# 42               4
# 43               4
# 44               4
# 45               5
# 46               4
# 47               4
# 48               4
# 49               4

# %%
audio_features_df.to_sql('audio_features', engine, if_exists="append", index=False)

# %%
artists_endpoint_url = f'https://api.spotify.com/v1/artists'

params = {'ids':artists_list_ids}

artists_api_request = requests.get(artists_endpoint_url, headers = headers, params= params )

# %%
artists_api_response = json.loads(artists_api_request.text)

# %%
artist_list = artists_api_response['artists']

# %%
artist_data = {
    'artist_id':[],
    'artist_name':[],
    'followers':[],
    'popularity':[]
}

for a in artist_list:
    
    artist_id = a['id']
    artist_data['artist_id'].append(artist_id)
    print(artist_id)
    
    artist_name = a['name']
    artist_data['artist_name'].append(artist_name)
    print(artist_name)
    
    followers = a['followers']['total']
    artist_data['followers'].append(followers)
    print(followers)
    
    popularity = a['popularity']
    artist_data['popularity'].append(popularity)
    print(popularity)
    
    print('--' * 75)
# Out:
# 5VZn4mB8pS40aE0kujdX2Y
# Chloe George
# 4935
# 59
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2KsP6tYLJlTBvSUxnwlVWa
# Mike Posner
# 1135060
# 77
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 7jVv8c5Fj3E9VhNjxT4snq
# Lil Nas X
# 4544008
# 89
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4IJczjB0fJ04gs4uvP0Fli
# Gym Class Heroes
# 1225179
# 78
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0du5cEVh5yTK9QJze8zA0C
# Bruno Mars
# 29832394
# 93
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1uU7g3DNSbsu0QjSEqZtEd
# Masked Wolf
# 171677
# 85
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1LZEQNv7sE11VDY3SdxQeN
# Bee Gees
# 4319509
# 80
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1uNFoZAHBGtllmzznpCI3s
# Justin Bieber
# 44506520
# 100
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2vnB6tuQMaQpORiRdvXF9H
# Beach Bunny
# 468180
# 76
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 5P2rwRBgIN450RaJxdjYdA
# Kardinal Offishall
# 41585
# 70
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 5pKCCKE2ajJHZ9KAiaK11H
# Rihanna
# 42194756
# 92
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6GMYJwaziB4ekv1Y6wCDWS
# Soulja Boy
# 1261231
# 72
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 25uiPmTg16RbhZWAqwLBy5
# Charli XCX
# 2290580
# 78
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1WgXqy2Dd70QQOU7Ay074N
# AURORA
# 1291274
# 78
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4kYSro6naA4h99UJvo89HB
# Cardi B
# 15729617
# 90
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1U1el3k54VvEUzo3ybLPlM
# Kali Uchis
# 1688000
# 88
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4b19vuzlDcNdU4quI7L6sW
# ElyOtto
# 56793
# 76
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0fA0VVWsXO9YnASrzqfmYu
# Kid Cudi
# 4739872
# 87
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4E2rKHVDssGJm2SCDOMMJB
# Iamdoechii
# 21151
# 57
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 7kRrkUEPgO3TRfAi7Gsw2i
# Reyanna Maria
# 8196
# 61
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6GkJh85o22LfD2vgL9DP6f
# Dirty Heads
# 603319
# 73
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6CwfuxIqcltXDGjfZsMd9A
# MARINA
# 2525944
# 78
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3PyJHH2wyfQK3WZrk9rpmP
# Ashnikko
# 912160
# 81
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2jw70GZXlAI8QzWeY2bgRc
# Nelly Furtado
# 2503420
# 78
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2SXhbucehn00OBVKhzxDyM
# Erica Banks
# 28799
# 71
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 54R6Y0I7jGUCveDTtI21nb
# Boney M.
# 935692
# 76
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 05YVYeV4HxYp5rrWalvuE1
# Grover Washington, Jr.
# 198861
# 71
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 26T3LtbuGT1Fu9m0eRq5X3
# Cage The Elephant
# 2455223
# 79
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3aQeKQSyrW4qWr35idm0cy
# T-Pain
# 3204889
# 82
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 15K8w0bfYieOr55vhSMgJN
# Edith Whiskers
# 38297
# 67
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3XxNRirzbjfLdDli06zMaB
# Eyedress
# 143514
# 71
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 77SW9BnxLY8rJ0RciFqkHh
# The Neighbourhood
# 5887201
# 86
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1gPhS1zisyXr5dHTYZyiMe
# Kevin Gates
# 4092347
# 82
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6DdbeAeBlrYj8bNToZv4TY
# JESSIA
# 81171
# 68
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3JG79Z23wJN9Q5PTPpDAEV
# kostromin
# 25847
# 66
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 63kE1M6nlHBGwRttAc4Q6Z
# Xilo
# 4546
# 56
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 5cj0lLjcoR7YOSnhnX0Po5
# Doja Cat
# 6164507
# 91
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0bBz5bRBkExaej2HxtVfCw
# 347aidan
# 180754
# 73
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 7Ln80lUS6He07XvHI8qqHH
# Arctic Monkeys
# 11457755
# 87
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2rhFzFmezpnW82MNqEKVry
# Ski Mask The Slump God
# 4078392
# 81
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 31TPClRtHm23RisEBtV3X7
# Justin Timberlake
# 10628700
# 84
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2YOYua8FpudSEiB9s88IgQ
# Yung Gravy
# 1082487
# 76
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 181bsRPaVXVlUKXrxwZfHK
# Megan Thee Stallion
# 3923595
# 88
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4NqH3V7GS0Igs1VyGMXEi8
# Mooski
# 16094
# 68
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1PKErrAhYFdfrDymGHRQRo
# Nathan Evans
# 91735
# 80
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2cFrymmkijnjDg9SS92EPM
# blackbear
# 4079937
# 87
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0wHeZY93Ede0g1jXaWsiFS
# LPB Poody
# 59240
# 67
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0e86yPdC41PGRkLp2Q1Bph
# Mother Mother
# 1653563
# 82
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
artists_df = pd.DataFrame(artist_data)

# %%
artists_df
# Out:
#                  artist_id             artist_name  followers  popularity
# 0   5VZn4mB8pS40aE0kujdX2Y            Chloe George       4935          59
# 1   2KsP6tYLJlTBvSUxnwlVWa             Mike Posner    1135060          77
# 2   7jVv8c5Fj3E9VhNjxT4snq               Lil Nas X    4544008          89
# 3   4IJczjB0fJ04gs4uvP0Fli        Gym Class Heroes    1225179          78
# 4   0du5cEVh5yTK9QJze8zA0C              Bruno Mars   29832394          93
# 5   1uU7g3DNSbsu0QjSEqZtEd             Masked Wolf     171677          85
# 6   1LZEQNv7sE11VDY3SdxQeN                Bee Gees    4319509          80
# 7   1uNFoZAHBGtllmzznpCI3s           Justin Bieber   44506520         100
# 8   2vnB6tuQMaQpORiRdvXF9H             Beach Bunny     468180          76
# 9   5P2rwRBgIN450RaJxdjYdA      Kardinal Offishall      41585          70
# 10  5pKCCKE2ajJHZ9KAiaK11H                 Rihanna   42194756          92
# 11  6GMYJwaziB4ekv1Y6wCDWS              Soulja Boy    1261231          72
# 12  25uiPmTg16RbhZWAqwLBy5              Charli XCX    2290580          78
# 13  1WgXqy2Dd70QQOU7Ay074N                  AURORA    1291274          78
# 14  4kYSro6naA4h99UJvo89HB                 Cardi B   15729617          90
# 15  1U1el3k54VvEUzo3ybLPlM              Kali Uchis    1688000          88
# 16  4b19vuzlDcNdU4quI7L6sW                 ElyOtto      56793          76
# 17  0fA0VVWsXO9YnASrzqfmYu                Kid Cudi    4739872          87
# 18  4E2rKHVDssGJm2SCDOMMJB              Iamdoechii      21151          57
# 19  7kRrkUEPgO3TRfAi7Gsw2i           Reyanna Maria       8196          61
# 20  6GkJh85o22LfD2vgL9DP6f             Dirty Heads     603319          73
# 21  6CwfuxIqcltXDGjfZsMd9A                  MARINA    2525944          78
# 22  3PyJHH2wyfQK3WZrk9rpmP                Ashnikko     912160          81
# 23  2jw70GZXlAI8QzWeY2bgRc           Nelly Furtado    2503420          78
# 24  2SXhbucehn00OBVKhzxDyM             Erica Banks      28799          71
# 25  54R6Y0I7jGUCveDTtI21nb                Boney M.     935692          76
# 26  05YVYeV4HxYp5rrWalvuE1  Grover Washington, Jr.     198861          71
# 27  26T3LtbuGT1Fu9m0eRq5X3       Cage The Elephant    2455223          79
# 28  3aQeKQSyrW4qWr35idm0cy                  T-Pain    3204889          82
# 29  15K8w0bfYieOr55vhSMgJN          Edith Whiskers      38297          67
# 30  3XxNRirzbjfLdDli06zMaB                Eyedress     143514          71
# 31  77SW9BnxLY8rJ0RciFqkHh       The Neighbourhood    5887201          86
# 32  1gPhS1zisyXr5dHTYZyiMe             Kevin Gates    4092347          82
# 33  6DdbeAeBlrYj8bNToZv4TY                  JESSIA      81171          68
# 34  3JG79Z23wJN9Q5PTPpDAEV               kostromin      25847          66
# 35  63kE1M6nlHBGwRttAc4Q6Z                    Xilo       4546          56
# 36  5cj0lLjcoR7YOSnhnX0Po5                Doja Cat    6164507          91
# 37  0bBz5bRBkExaej2HxtVfCw                347aidan     180754          73
# 38  7Ln80lUS6He07XvHI8qqHH          Arctic Monkeys   11457755          87
# 39  2rhFzFmezpnW82MNqEKVry  Ski Mask The Slump God    4078392          81
# 40  31TPClRtHm23RisEBtV3X7       Justin Timberlake   10628700          84
# 41  2YOYua8FpudSEiB9s88IgQ              Yung Gravy    1082487          76
# 42  181bsRPaVXVlUKXrxwZfHK     Megan Thee Stallion    3923595          88
# 43  4NqH3V7GS0Igs1VyGMXEi8                  Mooski      16094          68
# 44  1PKErrAhYFdfrDymGHRQRo            Nathan Evans      91735          80
# 45  2cFrymmkijnjDg9SS92EPM               blackbear    4079937          87
# 46  0wHeZY93Ede0g1jXaWsiFS               LPB Poody      59240          67
# 47  0e86yPdC41PGRkLp2Q1Bph           Mother Mother    1653563          82

# %%
artists_df.to_sql('artists', engine, if_exists="append", index=False)

# %%
track_endpoint_url = f'https://api.spotify.com/v1/tracks/'

params = {'ids':track_list_ids}

track_api_request = requests.get(track_endpoint_url, headers = headers, params= params )

# %%
track_api_response = json.loads(track_api_request.text)

# %%
track_list = track_api_response['tracks']

# %%
track_list
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#      'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#      'id': '5VZn4mB8pS40aE0kujdX2Y',
#      'name': 'Chloe George',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6W4tUP2tcem0izGTVzxx5g'},
#    'href': 'https://api.spotify.com/v1/albums/6W4tUP2tcem0izGTVzxx5g',
#    'id': '6W4tUP2tcem0izGTVzxx5g',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735b6327459f5454a084d656f0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025b6327459f5454a084d656f0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515b6327459f5454a084d656f0',
#      'width': 64}],
#    'name': 'ghost town (voice memo)',
#    'release_date': '2021-03-30',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6W4tUP2tcem0izGTVzxx5g'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#     'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#     'id': '5VZn4mB8pS40aE0kujdX2Y',
#     'name': 'Chloe George',
#     'type': 'artist',
#     'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 137250,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72104942'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0PKAijroHpnEtdY20bkGdr'},
#   'href': 'https://api.spotify.com/v1/tracks/0PKAijroHpnEtdY20bkGdr',
#   'id': '0PKAijroHpnEtdY20bkGdr',
#   'is_local': False,
#   'name': 'ghost town (voice memo)',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1dc760d2bfd12adfe1d5090dc48f35161242799d?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0PKAijroHpnEtdY20bkGdr'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#      'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#      'id': '2KsP6tYLJlTBvSUxnwlVWa',
#      'name': 'Mike Posner',
#      'type': 'artist',
#      'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2nnIlWcriIqcJtjduWcTRl'},
#    'href': 'https://api.spotify.com/v1/albums/2nnIlWcriIqcJtjduWcTRl',
#    'id': '2nnIlWcriIqcJtjduWcTRl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a98ac59b1f31230990d941a2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a98ac59b1f31230990d941a2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a98ac59b1f31230990d941a2',
#      'width': 64}],
#    'name': '31 Minutes to Takeoff',
#    'release_date': '2010-08-09',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:2nnIlWcriIqcJtjduWcTRl'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#     'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#     'id': '2KsP6tYLJlTBvSUxnwlVWa',
#     'name': 'Mike Posner',
#     'type': 'artist',
#     'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 196813,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJAY1000077'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6jg5SRvdGxvJ0DzNV0UqEK'},
#   'href': 'https://api.spotify.com/v1/tracks/6jg5SRvdGxvJ0DzNV0UqEK',
#   'id': '6jg5SRvdGxvJ0DzNV0UqEK',
#   'is_local': False,
#   'name': "Please Don't Go",
#   'popularity': 82,
#   'preview_url': 'https://p.scdn.co/mp3-preview/66706c36ab06b681bc2b5d269f7387ec0110e16f?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:6jg5SRvdGxvJ0DzNV0UqEK'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#      'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#      'id': '7jVv8c5Fj3E9VhNjxT4snq',
#      'name': 'Lil Nas X',
#      'type': 'artist',
#      'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5iZytG7j5DDp9RlsmkGI97'},
#    'href': 'https://api.spotify.com/v1/albums/5iZytG7j5DDp9RlsmkGI97',
#    'id': '5iZytG7j5DDp9RlsmkGI97',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ddb9cf14094fa5b3f8683b14',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ddb9cf14094fa5b3f8683b14',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ddb9cf14094fa5b3f8683b14',
#      'width': 64}],
#    'name': 'MONTERO (Call Me By Your Name)',
#    'release_date': '2021-03-26',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:5iZytG7j5DDp9RlsmkGI97'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#     'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#     'id': '7jVv8c5Fj3E9VhNjxT4snq',
#     'name': 'Lil Nas X',
#     'type': 'artist',
#     'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'}],
#   'available_markets': [],
#   'disc_number': 1,
#   'duration_ms': 137875,
#   'explicit': True,
#   'external_ids': {'isrc': 'USSM12100531'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3BZEcbdtXQSo7OrvKRJ6mb'},
#   'href': 'https://api.spotify.com/v1/tracks/3BZEcbdtXQSo7OrvKRJ6mb',
#   'id': '3BZEcbdtXQSo7OrvKRJ6mb',
#   'is_local': False,
#   'name': 'MONTERO (Call Me By Your Name)',
#   'popularity': 99,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3BZEcbdtXQSo7OrvKRJ6mb'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IJczjB0fJ04gs4uvP0Fli'},
#      'href': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli',
#      'id': '4IJczjB0fJ04gs4uvP0Fli',
#      'name': 'Gym Class Heroes',
#      'type': 'artist',
#      'uri': 'spotify:artist:4IJczjB0fJ04gs4uvP0Fli'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4Ug3M4a8wAEebndVIF65fX'},
#    'href': 'https://api.spotify.com/v1/albums/4Ug3M4a8wAEebndVIF65fX',
#    'id': '4Ug3M4a8wAEebndVIF65fX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f335d8387c3658831112f914',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f335d8387c3658831112f914',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f335d8387c3658831112f914',
#      'width': 64}],
#    'name': 'The Papercut Chronicles',
#    'release_date': '2005-02-22',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:4Ug3M4a8wAEebndVIF65fX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IJczjB0fJ04gs4uvP0Fli'},
#     'href': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli',
#     'id': '4IJczjB0fJ04gs4uvP0Fli',
#     'name': 'Gym Class Heroes',
#     'type': 'artist',
#     'uri': 'spotify:artist:4IJczjB0fJ04gs4uvP0Fli'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 243773,
#   'explicit': False,
#   'external_ids': {'isrc': 'US56V0407211'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2Lhdl74nwwVGOE2Gv35QuK'},
#   'href': 'https://api.spotify.com/v1/tracks/2Lhdl74nwwVGOE2Gv35QuK',
#   'id': '2Lhdl74nwwVGOE2Gv35QuK',
#   'is_local': False,
#   'name': "Cupid's Chokehold / Breakfast in America",
#   'popularity': 87,
#   'preview_url': 'https://p.scdn.co/mp3-preview/aa1ffc19b8b6b8cea5446b81b5ec3d1254231c94?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:2Lhdl74nwwVGOE2Gv35QuK'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'available_markets': ['AR',
#     'AU',
#     'BN',
#     'BO',
#     'BZ',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'DO',
#     'EC',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'ID',
#     'IN',
#     'KH',
#     'KR',
#     'LA',
#     'MO',
#     'MX',
#     'MY',
#     'NI',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PY',
#     'SG',
#     'SR',
#     'SV',
#     'TH',
#     'TL',
#     'TW',
#     'US',
#     'UY',
#     'VN'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1uyf3l2d4XYwiEqAb7t7fX'},
#    'href': 'https://api.spotify.com/v1/albums/1uyf3l2d4XYwiEqAb7t7fX',
#    'id': '1uyf3l2d4XYwiEqAb7t7fX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27378c6c624a95d1bd02ba1fa02',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0278c6c624a95d1bd02ba1fa02',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485178c6c624a95d1bd02ba1fa02',
#      'width': 64}],
#    'name': 'Doo-Wops & Hooligans',
#    'release_date': '2010-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:1uyf3l2d4XYwiEqAb7t7fX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'available_markets': ['AR',
#    'AU',
#    'BN',
#    'BO',
#    'BZ',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'DO',
#    'EC',
#    'GT',
#    'GY',
#    'HK',
#    'HN',
#    'ID',
#    'IN',
#    'KH',
#    'KR',
#    'LA',
#    'MO',
#    'MX',
#    'MY',
#    'NI',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PY',
#    'SG',
#    'SR',
#    'SV',
#    'TH',
#    'TL',
#    'TW',
#    'US',
#    'UY',
#    'VN'],
#   'disc_number': 1,
#   'duration_ms': 217866,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21001985'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/161DnLWsx1i3u1JT05lzqU'},
#   'href': 'https://api.spotify.com/v1/tracks/161DnLWsx1i3u1JT05lzqU',
#   'id': '161DnLWsx1i3u1JT05lzqU',
#   'is_local': False,
#   'name': 'Talking to the Moon',
#   'popularity': 83,
#   'preview_url': 'https://p.scdn.co/mp3-preview/97de5b6d487f491cddfb427c1612f45f5b3c9388?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:161DnLWsx1i3u1JT05lzqU'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uU7g3DNSbsu0QjSEqZtEd'},
#      'href': 'https://api.spotify.com/v1/artists/1uU7g3DNSbsu0QjSEqZtEd',
#      'id': '1uU7g3DNSbsu0QjSEqZtEd',
#      'name': 'Masked Wolf',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uU7g3DNSbsu0QjSEqZtEd'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/023KmMyB2DNZR3V8YKoET9'},
#    'href': 'https://api.spotify.com/v1/albums/023KmMyB2DNZR3V8YKoET9',
#    'id': '023KmMyB2DNZR3V8YKoET9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273214ace0e5ba30b74d19efb19',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02214ace0e5ba30b74d19efb19',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851214ace0e5ba30b74d19efb19',
#      'width': 64}],
#    'name': 'Astronaut In The Ocean',
#    'release_date': '2019-06-07',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:023KmMyB2DNZR3V8YKoET9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uU7g3DNSbsu0QjSEqZtEd'},
#     'href': 'https://api.spotify.com/v1/artists/1uU7g3DNSbsu0QjSEqZtEd',
#     'id': '1uU7g3DNSbsu0QjSEqZtEd',
#     'name': 'Masked Wolf',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uU7g3DNSbsu0QjSEqZtEd'}],
#   'available_markets': [],
#   'disc_number': 1,
#   'duration_ms': 132780,
#   'explicit': False,
#   'external_ids': {'isrc': 'AUFXV1900105'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0jdso14vaFnpRazMLEZovF'},
#   'href': 'https://api.spotify.com/v1/tracks/0jdso14vaFnpRazMLEZovF',
#   'id': '0jdso14vaFnpRazMLEZovF',
#   'is_local': False,
#   'name': 'Astronaut In The Ocean',
#   'popularity': 56,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0jdso14vaFnpRazMLEZovF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#      'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#      'id': '1LZEQNv7sE11VDY3SdxQeN',
#      'name': 'Bee Gees',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'}],
#    'available_markets': ['AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GH',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'KW',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4vAhQeeWkSjVn0p5GAaLBx'},
#    'href': 'https://api.spotify.com/v1/albums/4vAhQeeWkSjVn0p5GAaLBx',
#    'id': '4vAhQeeWkSjVn0p5GAaLBx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273324045726c4b0deb6cb7c875',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02324045726c4b0deb6cb7c875',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851324045726c4b0deb6cb7c875',
#      'width': 64}],
#    'name': 'How Can You Mend A Broken Heart',
#    'release_date': '2020-11-20',
#    'release_date_precision': 'day',
#    'total_tracks': 25,
#    'type': 'album',
#    'uri': 'spotify:album:4vAhQeeWkSjVn0p5GAaLBx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LZEQNv7sE11VDY3SdxQeN'},
#     'href': 'https://api.spotify.com/v1/artists/1LZEQNv7sE11VDY3SdxQeN',
#     'id': '1LZEQNv7sE11VDY3SdxQeN',
#     'name': 'Bee Gees',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LZEQNv7sE11VDY3SdxQeN'}],
#   'available_markets': ['AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GH',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KE',
#    'KH',
#    'KR',
#    'KW',
#    'LB',
#    'LK',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SN',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TT',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 196213,
#   'explicit': False,
#   'external_ids': {'isrc': 'NLF057790033'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2cX2coZS1PYBfPs8wgbdWE'},
#   'href': 'https://api.spotify.com/v1/tracks/2cX2coZS1PYBfPs8wgbdWE',
#   'id': '2cX2coZS1PYBfPs8wgbdWE',
#   'is_local': False,
#   'name': 'More Than A Woman - From "Saturday Night Fever" Soundtrack',
#   'popularity': 79,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0396e55e0afb98e464697b7e749b4b40d3a69363?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 17,
#   'type': 'track',
#   'uri': 'spotify:track:2cX2coZS1PYBfPs8wgbdWE'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#    'href': 'https://api.spotify.com/v1/albums/5dGWwsZ9iB2Xc3UKR0gif2',
#    'id': '5dGWwsZ9iB2Xc3UKR0gif2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e6f407c7f3a0ec98845e4431',
#      'width': 64}],
#    'name': 'Justice',
#    'release_date': '2021-03-19',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:5dGWwsZ9iB2Xc3UKR0gif2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'name': 'Justin Bieber',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#     'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#     'id': '20wkVLutqVOYrc0kxFs7rA',
#     'name': 'Daniel Caesar',
#     'type': 'artist',
#     'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#     'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#     'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#     'name': 'Giveon',
#     'type': 'artist',
#     'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 198081,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM72102636'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI'},
#   'href': 'https://api.spotify.com/v1/tracks/4iJyoBOLtHqaGxP12qzhQI',
#   'id': '4iJyoBOLtHqaGxP12qzhQI',
#   'is_local': False,
#   'name': 'Peaches (feat. Daniel Caesar & Giveon)',
#   'popularity': 100,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2d914ef1e42235bd50ba4f1c08f84d84ebb0bebc?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:4iJyoBOLtHqaGxP12qzhQI'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#      'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#      'id': '2vnB6tuQMaQpORiRdvXF9H',
#      'name': 'Beach Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#    'available_markets': ['AU', 'NZ'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1PAsUJFVKxmdofGFsFU3Df'},
#    'href': 'https://api.spotify.com/v1/albums/1PAsUJFVKxmdofGFsFU3Df',
#    'id': '1PAsUJFVKxmdofGFsFU3Df',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bc0e3acd005a2f3d136525cc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bc0e3acd005a2f3d136525cc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bc0e3acd005a2f3d136525cc',
#      'width': 64}],
#    'name': 'Honeymoon',
#    'release_date': '2020-02-14',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:1PAsUJFVKxmdofGFsFU3Df'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#     'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#     'id': '2vnB6tuQMaQpORiRdvXF9H',
#     'name': 'Beach Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#   'available_markets': ['AU', 'NZ'],
#   'disc_number': 1,
#   'duration_ms': 137600,
#   'explicit': False,
#   'external_ids': {'isrc': 'USQE91600054'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/589Lt4lVKxd1qXOrPaAHkB'},
#   'href': 'https://api.spotify.com/v1/tracks/589Lt4lVKxd1qXOrPaAHkB',
#   'id': '589Lt4lVKxd1qXOrPaAHkB',
#   'is_local': False,
#   'name': 'Cloud 9',
#   'popularity': 63,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2c08f232a2c54cf22681dde0450c08d08e224c1c?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:589Lt4lVKxd1qXOrPaAHkB'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P2rwRBgIN450RaJxdjYdA'},
#      'href': 'https://api.spotify.com/v1/artists/5P2rwRBgIN450RaJxdjYdA',
#      'id': '5P2rwRBgIN450RaJxdjYdA',
#      'name': 'Kardinal Offishall',
#      'type': 'artist',
#      'uri': 'spotify:artist:5P2rwRBgIN450RaJxdjYdA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AM',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BS',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LI',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MN',
#     'MT',
#     'MU',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'SZ',
#     'TD',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'UG',
#     'US',
#     'UZ',
#     'VN',
#     'XK',
#     'ZA',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4mvT7q9PuuBWZcVyUnZP8e'},
#    'href': 'https://api.spotify.com/v1/albums/4mvT7q9PuuBWZcVyUnZP8e',
#    'id': '4mvT7q9PuuBWZcVyUnZP8e',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cedc24abc2e757d13b386d1e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02cedc24abc2e757d13b386d1e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851cedc24abc2e757d13b386d1e',
#      'width': 64}],
#    'name': 'Not 4 Sale',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4mvT7q9PuuBWZcVyUnZP8e'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5P2rwRBgIN450RaJxdjYdA'},
#     'href': 'https://api.spotify.com/v1/artists/5P2rwRBgIN450RaJxdjYdA',
#     'id': '5P2rwRBgIN450RaJxdjYdA',
#     'name': 'Kardinal Offishall',
#     'type': 'artist',
#     'uri': 'spotify:artist:5P2rwRBgIN450RaJxdjYdA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#     'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#     'id': '0z4gvV4rjIZ9wHck67ucSV',
#     'name': 'Akon',
#     'type': 'artist',
#     'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AM',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BS',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DM',
#    'DO',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GB',
#    'GD',
#    'GH',
#    'GM',
#    'GN',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LI',
#    'LK',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MN',
#    'MT',
#    'MU',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'SZ',
#    'TD',
#    'TH',
#    'TN',
#    'TR',
#    'TT',
#    'TW',
#    'UA',
#    'UG',
#    'US',
#    'UZ',
#    'VN',
#    'XK',
#    'ZA',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 246053,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70830921'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4NOZ35Dhucr6UlVyLOtktd'},
#   'href': 'https://api.spotify.com/v1/tracks/4NOZ35Dhucr6UlVyLOtktd',
#   'id': '4NOZ35Dhucr6UlVyLOtktd',
#   'is_local': False,
#   'name': 'Dangerous',
#   'popularity': 82,
#   'preview_url': 'https://p.scdn.co/mp3-preview/324266f507f3b1e102f5a91b76d99a236da436b7?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:4NOZ35Dhucr6UlVyLOtktd'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#      'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#      'id': '5pKCCKE2ajJHZ9KAiaK11H',
#      'name': 'Rihanna',
#      'type': 'artist',
#      'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#    'available_markets': ['AD',
#     'AG',
#     'AM',
#     'AR',
#     'AU',
#     'AZ',
#     'BB',
#     'BD',
#     'BF',
#     'BG',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DJ',
#     'DM',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'GA',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HT',
#     'HU',
#     'ID',
#     'IL',
#     'IN',
#     'IS',
#     'JM',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KM',
#     'KN',
#     'KR',
#     'KZ',
#     'LA',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LV',
#     'MC',
#     'MD',
#     'MG',
#     'ML',
#     'MN',
#     'MO',
#     'MT',
#     'MU',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NZ',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'RU',
#     'RW',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SN',
#     'SR',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TR',
#     'TT',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UZ',
#     'VC',
#     'VN',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2g1EakEaW7fPTZC6vBmBCn'},
#    'href': 'https://api.spotify.com/v1/albums/2g1EakEaW7fPTZC6vBmBCn',
#    'id': '2g1EakEaW7fPTZC6vBmBCn',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bef074de9ca825bddaeb9f46',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bef074de9ca825bddaeb9f46',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bef074de9ca825bddaeb9f46',
#      'width': 64}],
#    'name': 'Talk That Talk',
#    'release_date': '2011-11-18',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:2g1EakEaW7fPTZC6vBmBCn'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#     'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#     'id': '5pKCCKE2ajJHZ9KAiaK11H',
#     'name': 'Rihanna',
#     'type': 'artist',
#     'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#   'available_markets': ['AD',
#    'AG',
#    'AM',
#    'AR',
#    'AU',
#    'AZ',
#    'BB',
#    'BD',
#    'BF',
#    'BG',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CY',
#    'CZ',
#    'DJ',
#    'DM',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'GA',
#    'GD',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HT',
#    'HU',
#    'ID',
#    'IL',
#    'IN',
#    'IS',
#    'JM',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KM',
#    'KN',
#    'KR',
#    'KZ',
#    'LA',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LV',
#    'MC',
#    'MD',
#    'MG',
#    'ML',
#    'MN',
#    'MO',
#    'MT',
#    'MU',
#    'MW',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NZ',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'RO',
#    'RU',
#    'RW',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SN',
#    'SR',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TR',
#    'TT',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UZ',
#    'VC',
#    'VN',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 242680,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71118074'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5WQQIDU3HRaMyPkob8mpFb'},
#   'href': 'https://api.spotify.com/v1/tracks/5WQQIDU3HRaMyPkob8mpFb',
#   'id': '5WQQIDU3HRaMyPkob8mpFb',
#   'is_local': False,
#   'name': 'Where Have You Been',
#   'popularity': 76,
#   'preview_url': 'https://p.scdn.co/mp3-preview/58c12c1496f0c42f4f4065120ee61c4eae1ede83?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:5WQQIDU3HRaMyPkob8mpFb'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6GMYJwaziB4ekv1Y6wCDWS'},
#      'href': 'https://api.spotify.com/v1/artists/6GMYJwaziB4ekv1Y6wCDWS',
#      'id': '6GMYJwaziB4ekv1Y6wCDWS',
#      'name': 'Soulja Boy',
#      'type': 'artist',
#      'uri': 'spotify:artist:6GMYJwaziB4ekv1Y6wCDWS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1l5ZuwSAlGfOrHRmoNNoL3'},
#    'href': 'https://api.spotify.com/v1/albums/1l5ZuwSAlGfOrHRmoNNoL3',
#    'id': '1l5ZuwSAlGfOrHRmoNNoL3',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273984533f3ee5c4fe8ba996ef2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02984533f3ee5c4fe8ba996ef2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851984533f3ee5c4fe8ba996ef2',
#      'width': 64}],
#    'name': 'She Make It Clap',
#    'release_date': '2021-03-12',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:1l5ZuwSAlGfOrHRmoNNoL3'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6GMYJwaziB4ekv1Y6wCDWS'},
#     'href': 'https://api.spotify.com/v1/artists/6GMYJwaziB4ekv1Y6wCDWS',
#     'id': '6GMYJwaziB4ekv1Y6wCDWS',
#     'name': 'Soulja Boy',
#     'type': 'artist',
#     'uri': 'spotify:artist:6GMYJwaziB4ekv1Y6wCDWS'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
# ...
#      'type': 'artist',
#      'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1TkwzY3l4LqAfrQwBAx45Q'},
#    'href': 'https://api.spotify.com/v1/albums/1TkwzY3l4LqAfrQwBAx45Q',
#    'id': '1TkwzY3l4LqAfrQwBAx45Q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bf33fdea7b0ff3c71b6faf75',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bf33fdea7b0ff3c71b6faf75',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bf33fdea7b0ff3c71b6faf75',
#      'width': 64}],
#    'name': 'deadroses',
#    'release_date': '2015-02-14',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:1TkwzY3l4LqAfrQwBAx45Q'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#     'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#     'id': '2cFrymmkijnjDg9SS92EPM',
#     'name': 'blackbear',
#     'type': 'artist',
#     'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 165600,
#   'explicit': True,
#   'external_ids': {'isrc': 'USLD90810521'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0qgZvYWLIqDn0tXimF8gPa'},
#   'href': 'https://api.spotify.com/v1/tracks/0qgZvYWLIqDn0tXimF8gPa',
#   'id': '0qgZvYWLIqDn0tXimF8gPa',
#   'is_local': False,
#   'name': 'dirty laundry',
#   'popularity': 76,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f84fc3a6fe1fc536d976ca57edb27971c09bc1b4?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:0qgZvYWLIqDn0tXimF8gPa'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wHeZY93Ede0g1jXaWsiFS'},
#      'href': 'https://api.spotify.com/v1/artists/0wHeZY93Ede0g1jXaWsiFS',
#      'id': '0wHeZY93Ede0g1jXaWsiFS',
#      'name': 'LPB Poody',
#      'type': 'artist',
#      'uri': 'spotify:artist:0wHeZY93Ede0g1jXaWsiFS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2XtDT9YT729iLxWjuTMtrR'},
#    'href': 'https://api.spotify.com/v1/albums/2XtDT9YT729iLxWjuTMtrR',
#    'id': '2XtDT9YT729iLxWjuTMtrR',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eb05db2aafb810d71d918a55',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eb05db2aafb810d71d918a55',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eb05db2aafb810d71d918a55',
#      'width': 64}],
#    'name': 'Batman',
#    'release_date': '2021-02-12',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2XtDT9YT729iLxWjuTMtrR'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wHeZY93Ede0g1jXaWsiFS'},
#     'href': 'https://api.spotify.com/v1/artists/0wHeZY93Ede0g1jXaWsiFS',
#     'id': '0wHeZY93Ede0g1jXaWsiFS',
#     'name': 'LPB Poody',
#     'type': 'artist',
#     'uri': 'spotify:artist:0wHeZY93Ede0g1jXaWsiFS'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 156431,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM72101263'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1xMvdOFQaql3EBkHmuh2TK'},
#   'href': 'https://api.spotify.com/v1/tracks/1xMvdOFQaql3EBkHmuh2TK',
#   'id': '1xMvdOFQaql3EBkHmuh2TK',
#   'is_local': False,
#   'name': 'Batman',
#   'popularity': 80,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b476e95fd0ddd7e1997a6148ee91db441b6bc1e7?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1xMvdOFQaql3EBkHmuh2TK'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#      'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#      'id': '0e86yPdC41PGRkLp2Q1Bph',
#      'name': 'Mother Mother',
#      'type': 'artist',
#      'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0X7S0TEZ5NJsSxmyTnfYi2'},
#    'href': 'https://api.spotify.com/v1/albums/0X7S0TEZ5NJsSxmyTnfYi2',
#    'id': '0X7S0TEZ5NJsSxmyTnfYi2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736d82586633548d5c122ee00c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026d82586633548d5c122ee00c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516d82586633548d5c122ee00c',
#      'width': 64}],
#    'name': 'O My Heart',
#    'release_date': '2008-09-23',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:0X7S0TEZ5NJsSxmyTnfYi2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0e86yPdC41PGRkLp2Q1Bph'},
#     'href': 'https://api.spotify.com/v1/artists/0e86yPdC41PGRkLp2Q1Bph',
#     'id': '0e86yPdC41PGRkLp2Q1Bph',
#     'name': 'Mother Mother',
#     'type': 'artist',
#     'uri': 'spotify:artist:0e86yPdC41PGRkLp2Q1Bph'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 181680,
#   'explicit': False,
#   'external_ids': {'isrc': 'CAL450882108'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2kS6td1yvmpNgZTt1q5pQq'},
#   'href': 'https://api.spotify.com/v1/tracks/2kS6td1yvmpNgZTt1q5pQq',
#   'id': '2kS6td1yvmpNgZTt1q5pQq',
#   'is_local': False,
#   'name': 'Hayloft',
#   'popularity': 86,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f7ea49e6d92e99190acff02665f2ce2b6de1da99?cid=774b29d4f13844c495f206cafdad9c86',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:2kS6td1yvmpNgZTt1q5pQq'}]

# %%
track_data = {
    'track_id':[],
    'track_name':[],
    'artist_id':[],
    'popularity':[],
    'duration_ms':[],
    'explicit':[]
}

for t in track_list:
    
    track_id = t['id']
    track_data['track_id'].append(track_id)
    print(track_id)
    
    track_name = t['name']
    track_data['track_name'].append(track_name)
    print(track_name)
    
    artist_id = t['artists'][0]['id']
    track_data['artist_id'].append(artist_id)
    print(artist_id)
    
    popularity = t['popularity']
    track_data['popularity'].append(popularity)
    print(popularity)
    
    duration_ms = t['duration_ms']
    track_data['duration_ms'].append(duration_ms)
    print(duration_ms)
    
    explicit = t['explicit']
    track_data['explicit'].append(explicit)
    print(explicit)
    
    print('--' * 75)
# Out:
# 0PKAijroHpnEtdY20bkGdr
# ghost town (voice memo)
# 5VZn4mB8pS40aE0kujdX2Y
# 73
# 137250
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6jg5SRvdGxvJ0DzNV0UqEK
# Please Don't Go
# 2KsP6tYLJlTBvSUxnwlVWa
# 82
# 196813
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3BZEcbdtXQSo7OrvKRJ6mb
# MONTERO (Call Me By Your Name)
# 7jVv8c5Fj3E9VhNjxT4snq
# 99
# 137875
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2Lhdl74nwwVGOE2Gv35QuK
# Cupid's Chokehold / Breakfast in America
# 4IJczjB0fJ04gs4uvP0Fli
# 87
# 243773
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 161DnLWsx1i3u1JT05lzqU
# Talking to the Moon
# 0du5cEVh5yTK9QJze8zA0C
# 83
# 217866
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0jdso14vaFnpRazMLEZovF
# Astronaut In The Ocean
# 1uU7g3DNSbsu0QjSEqZtEd
# 56
# 132780
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2cX2coZS1PYBfPs8wgbdWE
# More Than A Woman - From "Saturday Night Fever" Soundtrack
# 1LZEQNv7sE11VDY3SdxQeN
# 79
# 196213
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4iJyoBOLtHqaGxP12qzhQI
# Peaches (feat. Daniel Caesar & Giveon)
# 1uNFoZAHBGtllmzznpCI3s
# 100
# 198081
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 589Lt4lVKxd1qXOrPaAHkB
# Cloud 9
# 2vnB6tuQMaQpORiRdvXF9H
# 63
# 137600
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4NOZ35Dhucr6UlVyLOtktd
# Dangerous
# 5P2rwRBgIN450RaJxdjYdA
# 82
# 246053
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 5WQQIDU3HRaMyPkob8mpFb
# Where Have You Been
# 5pKCCKE2ajJHZ9KAiaK11H
# 76
# 242680
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2BKyXCkxhZRGwREqZacJ9M
# She Make It Clap
# 6GMYJwaziB4ekv1Y6wCDWS
# 70
# 111621
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3qGHAKgjQruzj6doKkyEb5
# Unlock it (feat. Kim Petras and Jay Park)
# 25uiPmTg16RbhZWAqwLBy5
# 75
# 232933
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0TCmhnbMpw5zwPsTvlXTJi
# Runaway
# 1WgXqy2Dd70QQOU7Ay074N
# 79
# 248826
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1M4OcYkxAtu3ErzSgDEfoi
# Up
# 4kYSro6naA4h99UJvo89HB
# 84
# 156944
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6tDDoYIxWvMLTdKpjFkc1B
# telepatía
# 1U1el3k54VvEUzo3ybLPlM
# 97
# 160191
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3FxPbp05KjMBa4HbhAJTH0
# SugarCrash!
# 4b19vuzlDcNdU4quI7L6sW
# 82
# 80117
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 60PAzFNW3vAiAiVK6DRJfB
# Day 'N' Nite (Nightmare)
# 0fA0VVWsXO9YnASrzqfmYu
# 76
# 221240
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1j3SdMJfeRJXycCp50boYE
# Yucky Blucky Fruitcake
# 4E2rKHVDssGJm2SCDOMMJB
# 69
# 275520
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1yLTcitjbEJr7a4jyDB0Lz
# So Pretty
# 7kRrkUEPgO3TRfAi7Gsw2i
# 73
# 85741
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 7lgvGRC1gN0JGgY9VGXsQT
# Vacation
# 6GkJh85o22LfD2vgL9DP6f
# 73
# 209142
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6IbnUaczZBT34DhaD6S18F
# Bubblegum Bitch
# 6CwfuxIqcltXDGjfZsMd9A
# 82
# 154666
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 11ZulcYY4lowvcQm4oe3VJ
# Slumber Party (feat. Princess Nokia)
# 3PyJHH2wyfQK3WZrk9rpmP
# 85
# 178404
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4wH4dJgrsxONID6KS2tDQM
# Maneater
# 2jw70GZXlAI8QzWeY2bgRc
# 79
# 258893
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 6NWdgyVsjp2bJ11PToXCr1
# Buss It
# 2SXhbucehn00OBVKhzxDyM
# 46
# 188734
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1zVMJGPMWKmD4cjTTyf68y
# Rasputin - Club Mix
# 54R6Y0I7jGUCveDTtI21nb
# 67
# 272226
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1ko2lVN0vKGUl9zrU0qSlT
# Just the Two of Us (feat. Bill Withers)
# 05YVYeV4HxYp5rrWalvuE1
# 82
# 237106
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2tznHmp70DxMyr2XhWLOW0
# Cigarette Daydreams
# 26T3LtbuGT1Fu9m0eRq5X3
# 72
# 208760
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1uH1Nd8vet2uoZSDFSDwbh
# Up Down (Do This All Day) (feat. B.o.B)
# 3aQeKQSyrW4qWr35idm0cy
# 75
# 231893
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 18V1UiYRvWYwn01CRDbbuR
# Home
# 15K8w0bfYieOr55vhSMgJN
# 72
# 197360
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 5s2zbxZI4Ym5LTKwjZHS2V
# Jealous
# 3XxNRirzbjfLdDli06zMaB
# 77
# 122338
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2QjOHCTQ1Jl3zawyYOpxh6
# Sweater Weather
# 77SW9BnxLY8rJ0RciFqkHh
# 90
# 240400
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2HYvkdq6lpFXkVz9Tfqi8r
# Big Gangsta
# 1gPhS1zisyXr5dHTYZyiMe
# 83
# 243462
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4pBhTGnL5N5KqsyqU58jee
# I'm not Pretty
# 6DdbeAeBlrYj8bNToZv4TY
# 71
# 118400
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4KrhaZm4JRkNO4HRdLvJIG
# Моя голова винтом (My head is spinning like a screw)
# 3JG79Z23wJN9Q5PTPpDAEV
# 80
# 140000
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4jY3GWEqlrTALvVE1j7VHI
# Aesthetic
# 63kE1M6nlHBGwRttAc4Q6Z
# 70
# 158435
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 60ynsPSSKe6O3sfwRnIBRf
# Streets
# 5cj0lLjcoR7YOSnhnX0Po5
# 94
# 226986
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 7CCCX50zGHMTuHsyKQy03l
# Dancing in My Room
# 0bBz5bRBkExaej2HxtVfCw
# 26
# 180121
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 48q0vSHcJdhK3IiXH8C5WJ
# Why'd You Only Call Me When You're High?
# 7Ln80lUS6He07XvHI8qqHH
# 65
# 161123
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3EikYy40GMSp8l5mDV6IQo
# Foot Fungus
# 2rhFzFmezpnW82MNqEKVry
# 79
# 129546
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4mCf3vQf7z0Yseo0RxAi3V
# Desperado
# 5pKCCKE2ajJHZ9KAiaK11H
# 78
# 186466
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0O45fw2L5vsWpdsOdXwNAR
# SexyBack (feat. Timbaland)
# 31TPClRtHm23RisEBtV3X7
# 81
# 242733
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 7L6G0wpIUiPXuvoo7qhb06
# oops!
# 2YOYua8FpudSEiB9s88IgQ
# 80
# 139759
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2gam98EZKrF9XuOkU13ApN
# Promiscuous
# 2jw70GZXlAI8QzWeY2bgRc
# 82
# 242293
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 4aarlAfLKVCTxUDNgbwhjH
# Cry Baby (feat. DaBaby)
# 181bsRPaVXVlUKXrxwZfHK
# 83
# 137983
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 5hChuUMe5iHfjkXgzj1D4b
# Track Star
# 4NqH3V7GS0Igs1VyGMXEi8
# 82
# 199706
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3iw6V4LH7yPj1ESORX9RIN
# Wellerman - Sea Shanty / 220 KID x Billen Ted Remix
# 1PKErrAhYFdfrDymGHRQRo
# 92
# 116750
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 0qgZvYWLIqDn0tXimF8gPa
# dirty laundry
# 2cFrymmkijnjDg9SS92EPM
# 76
# 165600
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1xMvdOFQaql3EBkHmuh2TK
# Batman
# 0wHeZY93Ede0g1jXaWsiFS
# 80
# 156431
# True
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2kS6td1yvmpNgZTt1q5pQq
# Hayloft
# 0e86yPdC41PGRkLp2Q1Bph
# 86
# 181680
# False
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
tracks_df = pd.DataFrame(track_data)
tracks_df
# Out:
#                   track_id                                         track_name  \
# 0   0PKAijroHpnEtdY20bkGdr                            ghost town (voice memo)
# 1   6jg5SRvdGxvJ0DzNV0UqEK                                    Please Don't Go
# 2   3BZEcbdtXQSo7OrvKRJ6mb                     MONTERO (Call Me By Your Name)
# 3   2Lhdl74nwwVGOE2Gv35QuK           Cupid's Chokehold / Breakfast in America
# 4   161DnLWsx1i3u1JT05lzqU                                Talking to the Moon
# 5   0jdso14vaFnpRazMLEZovF                             Astronaut In The Ocean
# 6   2cX2coZS1PYBfPs8wgbdWE  More Than A Woman - From "Saturday Night Fever...
# 7   4iJyoBOLtHqaGxP12qzhQI             Peaches (feat. Daniel Caesar & Giveon)
# 8   589Lt4lVKxd1qXOrPaAHkB                                            Cloud 9
# 9   4NOZ35Dhucr6UlVyLOtktd                                          Dangerous
# 10  5WQQIDU3HRaMyPkob8mpFb                                Where Have You Been
# 11  2BKyXCkxhZRGwREqZacJ9M                                   She Make It Clap
# 12  3qGHAKgjQruzj6doKkyEb5          Unlock it (feat. Kim Petras and Jay Park)
# 13  0TCmhnbMpw5zwPsTvlXTJi                                            Runaway
# 14  1M4OcYkxAtu3ErzSgDEfoi                                                 Up
# 15  6tDDoYIxWvMLTdKpjFkc1B                                          telepatía
# 16  3FxPbp05KjMBa4HbhAJTH0                                        SugarCrash!
# 17  60PAzFNW3vAiAiVK6DRJfB                           Day 'N' Nite (Nightmare)
# 18  1j3SdMJfeRJXycCp50boYE                             Yucky Blucky Fruitcake
# 19  1yLTcitjbEJr7a4jyDB0Lz                                          So Pretty
# 20  7lgvGRC1gN0JGgY9VGXsQT                                           Vacation
# 21  6IbnUaczZBT34DhaD6S18F                                    Bubblegum Bitch
# 22  11ZulcYY4lowvcQm4oe3VJ               Slumber Party (feat. Princess Nokia)
# 23  4wH4dJgrsxONID6KS2tDQM                                           Maneater
# 24  6NWdgyVsjp2bJ11PToXCr1                                            Buss It
# 25  1zVMJGPMWKmD4cjTTyf68y                                Rasputin - Club Mix
# 26  1ko2lVN0vKGUl9zrU0qSlT            Just the Two of Us (feat. Bill Withers)
# 27  2tznHmp70DxMyr2XhWLOW0                                Cigarette Daydreams
# 28  1uH1Nd8vet2uoZSDFSDwbh            Up Down (Do This All Day) (feat. B.o.B)
# 29  18V1UiYRvWYwn01CRDbbuR                                               Home
# 30  5s2zbxZI4Ym5LTKwjZHS2V                                            Jealous
# 31  2QjOHCTQ1Jl3zawyYOpxh6                                    Sweater Weather
# 32  2HYvkdq6lpFXkVz9Tfqi8r                                        Big Gangsta
# 33  4pBhTGnL5N5KqsyqU58jee                                     I'm not Pretty
# 34  4KrhaZm4JRkNO4HRdLvJIG  Моя голова винтом (My head is spinning like a ...
# 35  4jY3GWEqlrTALvVE1j7VHI                                          Aesthetic
# 36  60ynsPSSKe6O3sfwRnIBRf                                            Streets
# 37  7CCCX50zGHMTuHsyKQy03l                                 Dancing in My Room
# 38  48q0vSHcJdhK3IiXH8C5WJ           Why'd You Only Call Me When You're High?
# 39  3EikYy40GMSp8l5mDV6IQo                                        Foot Fungus
# 40  4mCf3vQf7z0Yseo0RxAi3V                                          Desperado
# 41  0O45fw2L5vsWpdsOdXwNAR                         SexyBack (feat. Timbaland)
# 42  7L6G0wpIUiPXuvoo7qhb06                                              oops!
# 43  2gam98EZKrF9XuOkU13ApN                                        Promiscuous
# 44  4aarlAfLKVCTxUDNgbwhjH                            Cry Baby (feat. DaBaby)
# 45  5hChuUMe5iHfjkXgzj1D4b                                         Track Star
# 46  3iw6V4LH7yPj1ESORX9RIN  Wellerman - Sea Shanty / 220 KID x Billen Ted ...
# 47  0qgZvYWLIqDn0tXimF8gPa                                      dirty laundry
# 48  1xMvdOFQaql3EBkHmuh2TK                                             Batman
# 49  2kS6td1yvmpNgZTt1q5pQq                                            Hayloft
#
#                  artist_id  popularity  duration_ms  explicit
# 0   5VZn4mB8pS40aE0kujdX2Y          73       137250     False
# 1   2KsP6tYLJlTBvSUxnwlVWa          82       196813     False
# 2   7jVv8c5Fj3E9VhNjxT4snq          99       137875      True
# 3   4IJczjB0fJ04gs4uvP0Fli          87       243773     False
# 4   0du5cEVh5yTK9QJze8zA0C          83       217866     False
# 5   1uU7g3DNSbsu0QjSEqZtEd          56       132780     False
# 6   1LZEQNv7sE11VDY3SdxQeN          79       196213     False
# 7   1uNFoZAHBGtllmzznpCI3s         100       198081      True
# 8   2vnB6tuQMaQpORiRdvXF9H          63       137600     False
# 9   5P2rwRBgIN450RaJxdjYdA          82       246053      True
# 10  5pKCCKE2ajJHZ9KAiaK11H          76       242680     False
# 11  6GMYJwaziB4ekv1Y6wCDWS          70       111621      True
# 12  25uiPmTg16RbhZWAqwLBy5          75       232933      True
# 13  1WgXqy2Dd70QQOU7Ay074N          79       248826     False
# 14  4kYSro6naA4h99UJvo89HB          84       156944      True
# 15  1U1el3k54VvEUzo3ybLPlM          97       160191     False
# 16  4b19vuzlDcNdU4quI7L6sW          82        80117      True
# 17  0fA0VVWsXO9YnASrzqfmYu          76       221240     False
# 18  4E2rKHVDssGJm2SCDOMMJB          69       275520      True
# 19  7kRrkUEPgO3TRfAi7Gsw2i          73        85741      True
# 20  6GkJh85o22LfD2vgL9DP6f          73       209142      True
# 21  6CwfuxIqcltXDGjfZsMd9A          82       154666     False
# 22  3PyJHH2wyfQK3WZrk9rpmP          85       178404      True
# 23  2jw70GZXlAI8QzWeY2bgRc          79       258893     False
# 24  2SXhbucehn00OBVKhzxDyM          46       188734      True
# 25  54R6Y0I7jGUCveDTtI21nb          67       272226     False
# 26  05YVYeV4HxYp5rrWalvuE1          82       237106     False
# 27  26T3LtbuGT1Fu9m0eRq5X3          72       208760     False
# 28  3aQeKQSyrW4qWr35idm0cy          75       231893      True
# 29  15K8w0bfYieOr55vhSMgJN          72       197360     False
# 30  3XxNRirzbjfLdDli06zMaB          77       122338     False
# 31  77SW9BnxLY8rJ0RciFqkHh          90       240400     False
# 32  1gPhS1zisyXr5dHTYZyiMe          83       243462      True
# 33  6DdbeAeBlrYj8bNToZv4TY          71       118400      True
# 34  3JG79Z23wJN9Q5PTPpDAEV          80       140000     False
# 35  63kE1M6nlHBGwRttAc4Q6Z          70       158435      True
# 36  5cj0lLjcoR7YOSnhnX0Po5          94       226986      True
# 37  0bBz5bRBkExaej2HxtVfCw          26       180121     False
# 38  7Ln80lUS6He07XvHI8qqHH          65       161123     False
# 39  2rhFzFmezpnW82MNqEKVry          79       129546      True
# 40  5pKCCKE2ajJHZ9KAiaK11H          78       186466     False
# 41  31TPClRtHm23RisEBtV3X7          81       242733      True
# 42  2YOYua8FpudSEiB9s88IgQ          80       139759      True
# 43  2jw70GZXlAI8QzWeY2bgRc          82       242293     False
# 44  181bsRPaVXVlUKXrxwZfHK          83       137983      True
# 45  4NqH3V7GS0Igs1VyGMXEi8          82       199706      True
# 46  1PKErrAhYFdfrDymGHRQRo          92       116750     False
# 47  2cFrymmkijnjDg9SS92EPM          76       165600      True
# 48  0wHeZY93Ede0g1jXaWsiFS          80       156431      True
# 49  0e86yPdC41PGRkLp2Q1Bph          86       181680     False

# %%
tracks_df.to_sql('tracks', engine, if_exists="append", index=False)
